# %% [markdown]
# # Netflix Movies and TV shows Recommendation system
#
# Algorithm : Content Based Filtering - word2vec for word embedding of text features
#
# Notebook summary
#
# 1. Import necessary libraries
#
# 2. Import required dataset
#
# 3. Data preprocessing for baseline model
#
# 4. Install necessary dependencies to leverage the word2vec word embedding model from gensim
#
# 5. Model 1 ( baseline model ) : Considering equal weights for all features ( limited feature )
#
# 6. Model 2 : Considering different weights for different features
#
# 7. Model 3 : Considering wider set of features with differentiated weighting

# %% [markdown]
# # 1. Import necessary libraries

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Import required dataset

# %%
df_netflix = pd.read_csv("netflix_titles.csv")
df_netflix.drop(
    columns=[
        "director",
        "cast",
        "country",
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# # 3. Data preprocessing for baseline model

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, a, cape...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1   [,, shows, international, mysteries, dramas, tv]
# 2  [action, &, ,, shows, adventure, international...
#
#                                          description  \
# 0  [end, them, his, to, in, of, johnson, and, bot...
# 1  [swimming, out, to, star, birth, privateschool...
# 2  [deadly, robbers, his, to, and, of, a, war, dr...
#
#                   title_list
# 0  [is, dick, dead, johnson]
# 1          [water, blood, &]
# 2                [ganglands]

# %% [markdown]
# # 4. Install necessary dependencies to leverage the word2vec word embedding model from gensim

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.17.0)

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in wv.key_to_index]
    list_[3] = [word for word in list_[3] if word in wv.key_to_index]
    list_[4] = [word for word in list_[4] if word in wv.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
len(matrix_netflix_vocab)
# Out:
# 8807

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['documentaries']),
#        list(['end', 'them', 'his', 'in', 'johnson', 'both', 'ways', 'as', 'stages', 'inventive', 'death', 'life', 'filmmaker', 'face', 'the', 'comical', 'father', 'inevitable', 'her', 'nears', 'kirsten', 'help']),
#        list(['is', 'dick', 'dead', 'johnson'])], dtype=object)

# %%
df_netflix_vocab.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1      [shows, international, mysteries, dramas, tv]
# 2  [action, &, shows, adventure, international, c...
#
#                                          description  \
# 0  [end, them, his, in, johnson, both, ways, as, ...
# 1  [swimming, out, star, birth, whether, party, t...
# 2  [deadly, robbers, his, war, drug, into, violen...
#
#                   title_list
# 0  [is, dick, dead, johnson]
# 1          [water, blood, &]
# 2                [ganglands]

# %% [markdown]
# # 5. Model 1 ( baseline model ) :  Considering equal weights for all features ( limited feature )

# %% [markdown]
# ### Define the recommendation function

# %%
from tqdm import tqdm


def recommendation(title):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in wv.key_to_index]
        list_[3] = [word for word in list_[3] if word in wv.key_to_index]
        list_[4] = [word for word in list_[4] if word in wv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            score_catg = wv.n_similarity(list1[2], list2[2])
            score_desc = wv.n_similarity(list1[3], list2[3])
            try:
                score_title = wv.n_similarity(list1[4], list2[4]) / 2
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )
    df_netflix_similarity["final_score"] = (
        df_netflix_similarity["score_title"]
        + df_netflix_similarity["score_category"]
        + df_netflix_similarity["score_description"]
    )
    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### Example 1 : Execution of recommendation function

# %%
recommendation("Grown Ups")
# Out:
# 100%|██████████| 8807/8807 [00:07<00:00, 1247.12it/s]
#                                 recommendation      title  score_title  \
# 183               American Pie 9: Girls' Rules  Grown Ups     0.137693
# 205                                    Work It  Grown Ups     0.067882
# 713                               Little Nicky  Grown Ups     0.110633
# 475                         Father of the Year  Grown Ups     0.103823
# 690               I Don't Know How She Does It  Grown Ups     0.095467
# 143                               Mean Girls 2  Grown Ups     0.092655
# 624  Blue Mountain State: The Rise of Thadland  Grown Ups     0.090477
# 799                       The First Wives Club  Grown Ups     0.103501
# 31                                        Poms  Grown Ups     0.093836
# 615                                Bebe's Kids  Grown Ups     0.090393
#
#      score_category  score_description  final_score
# 183             1.0           0.735336     1.873028
# 205             1.0           0.730738     1.798619
# 713             1.0           0.684654     1.795287
# 475             1.0           0.681855     1.785678
# 690             1.0           0.682575     1.778041
# 143             1.0           0.685147     1.777803
# 624             1.0           0.681724     1.772202
# 799             1.0           0.665402     1.768903
# 31              1.0           0.671998     1.765834
# 615             1.0           0.675039     1.765433

# %%
movies_to_check = ['Grown Ups',
"American Pie 9: Girls' Rules",
'Work It',
'Little Nicky',
'Father of the Year',
"I Don't Know How She Does It",
'Mean Girls 2',
'Blue Mountain State: The Rise of Thadland',
'The First Wives Club',
'Poms',
"Bebe's Kids"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                                      title   listed_in  \
# 27       s28                                  Grown Ups  [comedies]
# 348     s349                                       Poms  [comedies]
# 1459   s1460                               Mean Girls 2  [comedies]
# 1881   s1882               American Pie 9: Girls' Rules  [comedies]
# 2159   s2160                                    Work It  [comedies]
# 4761   s4762                         Father of the Year  [comedies]
# 6267   s6268                                Bebe's Kids  [comedies]
# 6340   s6341  Blue Mountain State: The Rise of Thadland  [comedies]
# 7044   s7045               I Don't Know How She Does It  [comedies]
# 7316   s7317                               Little Nicky  [comedies]
# 8301   s8302                       The First Wives Club  [comedies]
#
#                                             description  \
# 27    [loss, lake, their, basketball, junior, being,...
# 348   [funloving, moving, youngatheart, retirement, ...
# 1459  [school, daughter, way, his, to, of, pariah, s...
# 1881  [school, their, to, of, student, plans, a, hom...
# 2159  [school, mater, brilliant, to, senior, ’, and,...
# 4761  [seriously, dads, take, their, to, in, a, drun...
# 6267  [and, s, man, surprises, robin, with, but, beb...
# 6340  [school, teammates, his, star, in, and, party,...
# 7044  [personal, in, and, kate, mom, a, wife, yuppie...
# 7316  [his, to, devil, siblings, power, plans, dear,...
# 8301  [payback, their, twotiming, s, for, a, women, ...
#
#                                              title_list
# 27                                         [grown, ups]
# 348                                              [poms]
# 1459                                   [girls, mean, 2]
# 1881             [girls, pie, :, american, ', 9, rules]
# 2159                                         [work, it]
# 4761                            [father, year, of, the]
# 6267                                   [bebe, kids, 's]
# 6340  [state, rise, :, thadland, blue, mountain, of,...
# 7044             [how, n't, it, does, i, do, know, she]
# 7316                                    [little, nicky]
# 8301                          [first, club, wives, the]

# %% [markdown]
# ### Example 2 : Execution of recommendation function

# %%
recommendation("The Conjuring")
# Out:
# 100%|██████████| 8807/8807 [00:03<00:00, 2336.64it/s]
#                     recommendation          title  score_title  \
# 373               Conjuring Spirit  The Conjuring     0.370828
# 95                 The Conjuring 2  The Conjuring     0.423710
# 510  The Haunting of Molly Hartley  The Conjuring     0.214101
# 64               The Strange House  The Conjuring     0.158805
# 381                       Delirium  The Conjuring     0.124619
# 42                   The Strangers  The Conjuring     0.138922
# 86                       Insidious  The Conjuring     0.100749
# 163                   The Darkness  The Conjuring     0.126599
# 501               The Devil Inside  The Conjuring     0.156047
# 502                 The Diabolical  The Conjuring     0.218079
#
#      score_category  score_description  final_score
# 373        0.964287           0.691602     2.026717
# 95         0.913295           0.686553     2.023558
# 510        1.000000           0.712108     1.926209
# 64         0.964287           0.783240     1.906332
# 381        1.000000           0.776508     1.901127
# 42         1.000000           0.759049     1.897971
# 86         1.000000           0.783389     1.884138
# 163        1.000000           0.742380     1.868980
# 501        1.000000           0.700452     1.856499
# 502        0.924792           0.708371     1.851242

# %%
movies_to_check = ['The Conjuring',
"Conjuring Spirit",
'The Conjuring 2',
'The Haunting of Molly Hartley',
'The Strange House',
"Delirium",
'The Strangers',
'Insidious',
'The Darkness',
'The Devil Inside',
"The Diabolica"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                          title  \
# 607     s608                  The Strangers
# 887     s888              The Strange House
# 1118   s1119                      Insidious
# 1283   s1284                  The Conjuring
# 1284   s1285                The Conjuring 2
# 2382   s2383                   The Darkness
# 6527   s6528               Conjuring Spirit
# 6590   s6591                       Delirium
# 8276   s8277               The Devil Inside
# 8338   s8339  The Haunting of Molly Hartley
#
#                                           listed_in  \
# 607                  [horror, ,, thrillers, movies]
# 887   [,, horror, thrillers, international, movies]
# 1118                 [horror, ,, thrillers, movies]
# 1283                 [horror, ,, thrillers, movies]
# 1284                               [horror, movies]
# 2382                 [horror, ,, thrillers, movies]
# 6527  [,, horror, thrillers, international, movies]
# 6590                 [horror, ,, thrillers, movies]
# 8276                 [horror, ,, thrillers, movies]
# 8338                 [horror, ,, thrillers, movies]
#
#                                             description  \
# 607   [stay, they, for, a, remote, intruders, under,...
# 887   [moves, haunts, their, that, to, and, town, tr...
# 1118  [moves, events, their, where, begin, to, in, a...
# 1283  [rhode, pair, farmhouse, help, of, island, sup...
# 1284  [daughter, releases, spirit, their, woman, to,...
# 2382  [boy, grand, that, to, his, of, canyon, a, anc...
# 6527  [betrayal, encounters, moves, spirit, receives...
# 6590  [moves, his, to, of, and, be, haunted, man, a,...
# 8276  [woman, to, and, s, a, once, mother, behind, e...
# 8338  [school, to, up, a, with, but, girl, destined,...
#
#                                title_list
# 607                      [strangers, the]
# 887                 [strange, house, the]
# 1118                          [insidious]
# 1283                     [conjuring, the]
# 1284                  [2, conjuring, the]
# 2382                      [darkness, the]
# 6527                  [conjuring, spirit]
# 6590                           [delirium]
# 8276                 [devil, inside, the]
# 8338  [haunting, hartley, of, molly, the]

# %% [markdown]
# # 6. Model 2 : Considering different weights for different features

# %% [markdown]
# ### Defining the recommendation function with different weights to be considered for different features

# %%
def recommendation(title, weight_title=0.5, weight_category=1.0, weight_description=1.0):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in wv.key_to_index]
        list_[3] = [word for word in list_[3] if word in wv.key_to_index]
        list_[4] = [word for word in list_[4] if word in wv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            score_catg = wv.n_similarity(list1[2], list2[2])
            score_desc = wv.n_similarity(list1[3], list2[3])
            try:
                score_title = wv.n_similarity(list1[4], list2[4])
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )

    # Calculate the final score incorporating weights
    df_netflix_similarity["final_score"] = (
        weight_title * df_netflix_similarity["score_title"]
        + weight_category * df_netflix_similarity["score_category"]
        + weight_description * df_netflix_similarity["score_description"]
    )

    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### example 1

# %%
recommendation("Grown Ups", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:05<00:00, 1700.86it/s]
#                                 recommendation      title  score_title  \
# 183               American Pie 9: Girls' Rules  Grown Ups     0.275386
# 205                                    Work It  Grown Ups     0.135764
# 713                               Little Nicky  Grown Ups     0.221265
# 475                         Father of the Year  Grown Ups     0.207646
# 143                               Mean Girls 2  Grown Ups     0.185311
# 690               I Don't Know How She Does It  Grown Ups     0.190933
# 624  Blue Mountain State: The Rise of Thadland  Grown Ups     0.180955
# 688                         How to Be a Player  Grown Ups     0.132778
# 799                       The First Wives Club  Grown Ups     0.207002
# 615                                Bebe's Kids  Grown Ups     0.180786
#
#      score_category  score_description  final_score
# 183             1.0           0.735336     1.870884
# 205             1.0           0.730738     1.825319
# 713             1.0           0.684654     1.814103
# 475             1.0           0.681855     1.807777
# 143             1.0           0.685147     1.803711
# 690             1.0           0.682575     1.803340
# 624             1.0           0.681724     1.799666
# 688             1.0           0.694481     1.795418
# 799             1.0           0.665402     1.794422
# 615             1.0           0.675039     1.794267

# %% [markdown]
# ### Example 2

# %%
recommendation("Jeans", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:06<00:00, 1453.40it/s]
#                   recommendation  title  score_title  score_category  \
# 541                Shimla Mirchi  Jeans     0.202888             1.0
# 435           Lock Your Girls In  Jeans     0.218440             1.0
# 822       Tere Naal Love Ho Gaya  Jeans     0.201543             1.0
# 59                   Flower Girl  Jeans     0.219998             1.0
# 313           A Chaster Marriage  Jeans     0.080294             1.0
# 114  Kambili: The Whole 30 Yards  Jeans     0.084734             1.0
# 453                    Zaki Chan  Jeans     0.101540             1.0
# 440          The Married Couples  Jeans     0.190842             1.0
# 223                 Hire a Woman  Jeans     0.204355             1.0
# 465                 Rich in Love  Jeans     0.135829             1.0
#
#      score_description  final_score
# 541           0.838650     1.931786
# 435           0.831262     1.930541
# 822           0.804745     1.904259
# 59            0.797348     1.903878
# 313           0.849080     1.903352
# 114           0.839707     1.897186
# 453           0.828308     1.893109
# 440           0.790251     1.889453
# 223           0.782599     1.887386
# 465           0.806073     1.885607

# %% [markdown]
# # 7. Model 3 : Considering wider set of features with differentiated weighting
#
# Features considered for content based filtering are title , director , cast , country , genre(listed_in) , description
#
# basic weights are applied to different features to explain the possibility , generally weights are allocated in conjunction with the functional expert

# %% [markdown]
# ### Load the dataset

# %%
# Load data
df_netflix = pd.read_csv("netflix_titles.csv")

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Remove features not to be considered for recommendation engine

# %%
df_netflix.drop(
    columns=[
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title         director  \
# 0      s1  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2         Blood & Water              NaN
# 2      s3             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'listed_in',
#        'description'],
#       dtype='object')

# %% [markdown]
# ### Data preprocessing

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["director"] = df_netflix["director"].str.lower()
df_netflix["cast"] = df_netflix["cast"].str.lower()
df_netflix["country"] = df_netflix["country"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

# Fill NaN values with empty strings and convert lists to strings
for col in ["director", "cast", "country"]:
    df_netflix[col] = df_netflix[col].fillna('').astype(str).apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["director"] = df_netflix["director"].apply(word_tokenize)
df_netflix["cast"] = df_netflix["cast"].apply(word_tokenize)
df_netflix["country"] = df_netflix["country"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [kirsten, johnson]
# 1      s2         Blood & Water                  []
# 2      s3             Ganglands  [julien, leclercq]
#
#                                                 cast           country  \
# 0                                                 []  [united, states]
# 1  [ama, qamata, ,, khosi, ngema, ,, gail, mabala...   [south, africa]
# 2  [sami, bouajila, ,, tracy, gotoas, ,, samuel, ...                []
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["director"] = df_netflix["director"].apply(lambda x: list(set(x)))
df_netflix["cast"] = df_netflix["cast"].apply(lambda x: list(set(x)))
df_netflix["country"] = df_netflix["country"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(2)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [kirsten, johnson]
# 1      s2         Blood & Water                  []
#
#                                                 cast           country  \
# 0                                                 []  [states, united]
# 1  [greeff, ryle, gwanya, fincham, molaba, ,, sit...   [africa, south]
#
#                                           listed_in  \
# 0                                   [documentaries]
# 1  [,, shows, international, mysteries, dramas, tv]
#
#                                          description  \
# 0  [end, them, his, to, in, of, johnson, and, bot...
# 1  [swimming, out, to, star, birth, privateschool...
#
#                   title_list
# 0  [is, dick, dead, johnson]
# 1          [water, blood, &]

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in wv.key_to_index]
    list_[3] = [word for word in list_[3] if word in wv.key_to_index]
    list_[4] = [word for word in list_[4] if word in wv.key_to_index]
    list_[5] = [word for word in list_[5] if word in wv.key_to_index]
    list_[6] = [word for word in list_[6] if word in wv.key_to_index]
    list_[7] = [word for word in list_[7] if word in wv.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['kirsten', 'johnson']),
#        list([]), list(['states', 'united']), list(['documentaries']),
#        list(['end', 'them', 'his', 'in', 'johnson', 'both', 'ways', 'as', 'stages', 'inventive', 'death', 'life', 'filmmaker', 'face', 'the', 'comical', 'father', 'inevitable', 'her', 'nears', 'kirsten', 'help']),
#        list(['is', 'dick', 'dead', 'johnson'])], dtype=object)

# %% [markdown]
# ### Defining the recommendation engine function

# %%
def recommendation(title, weight_title=1.0, weight_director=1.0, weight_cast=1.0,
                   weight_country=1.0, weight_genre=1.0, weight_description=1.0):

    # Extract the selected movie's features based on title
    matrix_netflix_title_vocab = []
    target_movies = df_netflix[df_netflix["title"] == title]

    if target_movies.empty:
        print(f"'{title}' not found in the dataset.")
        return pd.DataFrame()

    for list_ in target_movies.to_numpy():
        list_[2] = [word for word in list_[2] if word in wv.key_to_index]
        list_[3] = [word for word in list_[3] if word in wv.key_to_index]
        list_[4] = [word for word in list_[4] if word in wv.key_to_index]
        list_[5] = [word for word in list_[5] if word in wv.key_to_index]
        list_[6] = [word for word in list_[6] if word in wv.key_to_index]
        list_[7] = [word for word in list_[7] if word in wv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(df_netflix.to_numpy(), total=len(df_netflix))
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:

            # Calculate similarity scores for each feature, handling empty lists
            score_director = wv.n_similarity(list1[2], list2[2]) if list1[2] and list2[2] else 0  # Handle empty lists
            score_cast = wv.n_similarity(list1[3], list2[3]) if list1[3] and list2[3] else 0  # Handle empty lists
            score_country = wv.n_similarity(list1[4], list2[4]) if list1[4] and list2[4] else 0  # Handle empty lists
            score_catg = wv.n_similarity(list1[5], list2[5]) if list1[5] and list2[5] else 0  # Handle empty lists
            score_desc = wv.n_similarity(list1[6], list2[6]) if list1[6] and list2[6] else 0  # Handle empty lists

            # Handle title similarity calculation with try-except
            try:
                score_title = wv.n_similarity(list1[7], list2[7])
            except KeyError:
                score_title = 0

            # If the titles are different and genre similarity is significant
            if list1[1] != list2[1] and score_catg > 0.85:
                # Calculate the weighted final score
                final_score = (
                    weight_title * score_title +
                    weight_director * score_director +
                    weight_cast * score_cast +
                    weight_country * score_country +
                    weight_genre * score_catg +
                    weight_description * score_desc
                )

                # Append all relevant scores for the DataFrame
                matrix_similarity.append([list1[1], score_title, score_director, score_country, score_catg, score_desc, final_score])

    pbar.close()

    # Create DataFrame of recommendations and sort by final score
    df_netflix_similarity = pd.DataFrame(matrix_similarity, columns=["recommendation", "score_title" , "score_director" ,"score_country","score_genre" , "score_description" , "final_score"])
    return df_netflix_similarity.sort_values(by="final_score", ascending=False).head(10)

# %% [markdown]
# ### Example 1 : execution of the recommendation engine

# %%
recommendation("Jeans", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:06<00:00, 1320.84it/s]
#               recommendation  score_title  score_director  score_country  \
# 1319         Story of an Egg     0.144990        0.487648            1.0
# 541            Shimla Mirchi     0.202888        0.444767            1.0
# 673                    Shabd     0.000000        0.546363            1.0
# 822   Tere Naal Love Ho Gaya     0.201543        0.487452            1.0
# 746             Rajma Chawal     0.239810        0.546363            1.0
# 639          Marriage Palace     0.072713        0.542512            1.0
# 852           Running Shaadi     0.148171        0.496246            1.0
# 501       Kuch Kuch Hota Hai     0.157871        0.528753            1.0
# 817                   Fitoor     0.000000        0.609172            1.0
# 709                    Fatso     0.199852        0.549578            1.0
#
#       score_genre  score_description  final_score
# 1319     1.000000           0.765636     3.261040
# 541      1.000000           0.838650     3.227988
# 673      0.927278           0.724035     3.200233
# 822      1.000000           0.804745     3.189120
# 746      0.905684           0.794010     3.186901
# 639      0.935580           0.836553     3.172426
# 852      1.000000           0.721104     3.164321
# 501      0.905684           0.829632     3.154470
# 817      0.927278           0.743982     3.153724
# 709      0.905684           0.721141     3.152828

# %%
movies_to_check = ['Jeans',
"Story of an Egg",
'Shimla Mirchi',
'Shabd',
'Tere Naal Love Ho Gaya',
"Rajma Chawa",
'Marriage Palace',
'Running Shaadi',
'Kuch Kuch Hota Hai',
'Fitoor',
"Fatso"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                   title            director  \
# 24       s25                   Jeans       [shankar, s.]
# 2734   s2735      Kuch Kuch Hota Hai      [karan, johar]
# 2985   s2986           Shimla Mirchi     [sippy, ramesh]
# 3564   s3565         Marriage Palace     [sunil, thakur]
# 3917   s3918                   Shabd      [leena, yadav]
# 4103   s4104                   Fatso     [rajat, kapoor]
# 4722   s4723                  Fitoor  [abhishek, kapoor]
# 4735   s4736  Tere Naal Love Ho Gaya    [mandeep, kumar]
# 4904   s4905          Running Shaadi         [amit, roy]
# 8098   s8099         Story of an Egg   [b., raj, shetty]
#
#                                                    cast  country  \
# 24    [rai, sri, ,, prashanth, aishwarya, bachchan, ...  [india]
# 2734  [saeed, ,, rukh, jalal, shah, farida, khan, mu...  [india]
# 2985  [rao, preet, hema, shakti, rakul, gill, ,, kap...  [india]
# 3564  [., sharma, sangha, roopi, ,, sharry, nirmal, ...  [india]
# 3917  [siddiqui, rai, ,, kala, kamini, sadiya, zayed...  [india]
# 4103  [atul, ,, bakshi, kala, achrekar, panag, gul, ...  [india]
# 4722  [kaif, tabu, rahul, bhatt, rao, hydari, ,, kat...  [india]
# 4735  [cheema, ,, jaykar, om, riteish, anand, prabha...  [india]
# 4904  [arsh, amit, ,, bhullar, kala, jha, sadh, mohi...  [india]
# 8098  [rai, ,, shailashree, prakash, amrutha, usha, ...  [india]
#
#                                            listed_in  \
# 24    [romantic, comedies, ,, international, movies]
# 2734    [comedies, ,, international, dramas, movies]
# 2985  [romantic, comedies, ,, international, movies]
# 3564            [movies, comedies, international, ,]
# 3917    [romantic, ,, international, dramas, movies]
# 4103    [comedies, ,, international, dramas, movies]
# 4722    [romantic, ,, international, dramas, movies]
# 4735  [romantic, comedies, ,, international, movies]
# 4904  [romantic, comedies, ,, international, movies]
# 8098  [romantic, comedies, ,, international, movies]
#
#                                             description  \
# 24    [marry, woman, that, his, of, be, man, a, conv...
# 2734  [out, loved, woman, to, ’, s, a, with, reunite...
# 2985  [letter, his, to, in, tonguetied, of, up, s, m...
# 3564  [on, marry, bride, their, his, to, swap, man, ...
# 3917  [line, grows, his, to, and, a, seeks, wife, ur...
# 4103  [error, on, his, to, in, of, portly, man, a, w...
# 4722  [trained, woman, in, of, bitter, for, a, mothe...
# 4735  [rich, own, to, and, s, man, for, a, with, who...
# 4904  [daughter, his, migrant, to, elope, of, a, for...
# 8098  [out, bride, to, being, year, a, alone, gives,...
#
#                         title_list
# 24                         [jeans]
# 2734             [hai, hota, kuch]
# 2985              [shimla, mirchi]
# 3564            [marriage, palace]
# 3917                       [shabd]
# 4103                       [fatso]
# 4722                      [fitoor]
# 4735  [naal, ho, gaya, tere, love]
# 4904             [running, shaadi]
# 8098          [egg, an, of, story]

# %% [markdown]
# ### Example 2 : execution of the recommendation engine

# %%
recommendation("Dark", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:07<00:00, 1215.72it/s]
#        recommendation  score_title  score_director  score_country  \
# 182       In The Dark     0.821786               0       0.815271
# 184       Dark Desire     0.718159               0       0.462665
# 193         The Woods     0.378318               0       0.887903
# 350  When They See Us     0.215027               0       0.815271
# 108    Invisible City     0.337146               0       0.404001
# 495   The Frozen Dead     0.290684               0       0.460444
# 431    Dogs of Berlin     0.096403               0       0.747093
# 339        Black Spot     0.350655               0       0.503075
# 624        Deep Water     0.282871               0       0.443549
# 430         Travelers     0.052719               0       0.812040
#
#      score_genre  score_description  final_score
# 182     0.961960           0.606756     2.926603
# 184     0.922875           0.695216     2.775437
# 193     1.000000           0.674035     2.709436
# 350     0.961960           0.665618     2.698001
# 108     1.000000           0.717482     2.684233
# 495     1.000000           0.628069     2.636680
# 431     1.000000           0.646366     2.631375
# 339     1.000000           0.571254     2.627470
# 624     1.000000           0.602855     2.619751
# 430     1.000000           0.663855     2.605853

# %%
movies_to_check = ['Dark',
"In The Dark",
'Dark Desire',
'The Woods',
'When They See Us',
"Invisible City",
'The Frozen Dead',
'Dogs of Berlin',
'Black Spot',
'Deep Water',
"Travelers"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id             title director  \
# 1339   s1340    Invisible City       []
# 2229   s2230       In The Dark       []
# 2235   s2236       Dark Desire       []
# 2327   s2328              Dark       []
# 2401   s2402         The Woods       []
# 3746   s3747        Black Spot       []
# 3792   s3793  When They See Us       []
# 4310   s4311         Travelers       []
# 4316   s4317    Dogs of Berlin       []
# 5099   s5100   The Frozen Dead       []
# 6587   s6588        Deep Water       []
#
#                                                    cast  \
# 1339  [jéssica, manu, ,, marco, lago, córes, fábio, ...
# 2229  [brooke, rich, york, ,, krantz, keston, perry,...
# 2235  [leticia, merlo, ,, orozco, pineda, alejandro,...
# 2327  [winkler, ,, sebastian, mendl, michael, schöne...
# 2401  [,, martyna, adam, hubert, grzegorz, jacek, by...
# 3746  [,, naidra, hubert, renaud, daviot, suliane, o...
# 3792  [,, caleel, farmiga, jerome, harris, michael, ...
# 4310  [reilly, eric, patrick, paul, ,, gilmore, coop...
# 4316  [,, sebastian, schüttler, bennent, anna, krame...
# 5099  [lubna, ,, plagnol, ny, le, meurisse, charles,...
# 6587  [noah, julian, ,, victoria, olivia, william, c...
#
#                            country  \
# 1339                      [brazil]
# 2229              [states, united]
# 2235                      [mexico]
# 2327  [germany, states, united, ,]
# 2401   [states, ,, united, poland]
# 3746          [france, belgium, ,]
# 3792              [states, united]
# 4310   [states, canada, united, ,]
# 4316                     [germany]
# 5099                      [france]
# 6587                   [australia]
#
#                                               listed_in  \
# 1339       [,, shows, international, crime, dramas, tv]
# 2229                      [,, shows, crime, dramas, tv]
# 2235  [spanish-language, ,, shows, international, cr...
# 2327       [,, shows, international, crime, dramas, tv]
# 2401       [,, shows, international, crime, dramas, tv]
# 3746       [,, shows, international, crime, dramas, tv]
# 3792                      [,, shows, crime, dramas, tv]
# 4310       [,, shows, international, crime, dramas, tv]
# 4316       [,, shows, international, crime, dramas, tv]
# 5099       [,, shows, international, crime, dramas, tv]
# 6587       [,, shows, international, crime, dramas, tv]
#
#                                             description             title_list
# 1339  [his, to, and, man, they, a, realizes, living,...      [invisible, city]
# 2229  [woman, in, of, up, a, with, murder, investiga...        [in, dark, the]
# 2235  [those, passion, that, to, in, away, and, a, e...         [desire, dark]
# 2327  [on, child, that, they, for, a, hunt, answers,...                 [dark]
# 2401  [on, earlier, that, his, in, of, be, prosecuto...           [woods, the]
# 3746  [edge, in, and, of, prosecutor, town, a, isola...          [black, spot]
# 3792  [on, central, accused, harlem, in, of, they, a...  [when, us, they, see]
# 4310  [future, to, suddenly, s, a, agent, possess, d...            [travelers]
# 4316  [cops, case, them, that, in, of, a, famous, bu...     [dogs, berlin, of]
# 5099  [investigator, in, a, with, into, martin, this...    [frozen, dead, the]
# 6587  [grew, earlier, gay, where, to, in, and, up, s...          [water, deep]
