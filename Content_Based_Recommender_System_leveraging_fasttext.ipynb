# %% [markdown]
# # Netflix Movies and TV shows Recommendation system
#
# Algorithm : Content Based Filtering - fasttext for word embedding of text features
#
# Notebook summary
#
# 1. Import necessary libraries
#
# 2. Import required dataset
#
# 3. Data preprocessing for baseline model
#
# 4. Install necessary dependencies to leverage the fasttext word embedding model from gensim
#
# 5. Model 1 ( baseline model ) : Considering equal weights for all features ( limited feature )
#
# 6. Model 2 : Considering different weights for different features
#
# 7. Model 3 : Considering wider set of features with differentiated weighting

# %% [markdown]
# # 1. Import necessary libraries

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Import required dataset

# %%
df_netflix = pd.read_csv("netflix_titles.csv")
df_netflix.drop(
    columns=[
        "director",
        "cast",
        "country",
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# # 3. Data preprocessing for baseline model

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, a, cape...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1   [mysteries, dramas, shows, ,, tv, international]
# 2  [crime, adventure, shows, action, ,, tv, inter...
#
#                                          description  \
# 0  [johnson, kirsten, inventive, death, life, and...
# 1  [party, birth, her, sister, paths, swimming, w...
# 2  [deadly, protect, and, expert, from, powerful,...
#
#                   title_list
# 0  [is, dick, johnson, dead]
# 1          [blood, water, &]
# 2                [ganglands]

# %% [markdown]
# # 4. Install necessary dependencies to leverage the fasttext word embedding model from gensim

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.17.0)

# %%
import gensim

# %%
import gensim.downloader as api

FT = api.load('fasttext-wiki-news-subwords-300')
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in FT.key_to_index]
    list_[3] = [word for word in list_[3] if word in FT.key_to_index]
    list_[4] = [word for word in list_[4] if word in FT.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
len(matrix_netflix_vocab)
# Out:
# 8807

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['documentaries']),
#        list(['johnson', 'kirsten', 'inventive', 'death', 'life', 'and', 'in', 'her', 'face', 'help', 'filmmaker', 'them', 'to', 'of', 'end', 'both', 'nears', 'comical', 'as', 'stages', 'the', 'father', 'inevitable', 'his', 'ways']),
#        list(['is', 'dick', 'johnson', 'dead'])], dtype=object)

# %%
df_netflix_vocab.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1   [mysteries, dramas, shows, ,, tv, international]
# 2  [crime, adventure, shows, action, ,, tv, inter...
#
#                                          description  \
# 0  [johnson, kirsten, inventive, death, life, and...
# 1  [party, birth, her, sister, paths, swimming, w...
# 2  [deadly, protect, and, expert, from, powerful,...
#
#                   title_list
# 0  [is, dick, johnson, dead]
# 1          [blood, water, &]
# 2                         []

# %% [markdown]
# # 5. Model 1 ( baseline model ) :  Considering equal weights for all features ( limited feature )

# %% [markdown]
# ### Define the recommendation function

# %%
from tqdm import tqdm


def recommendation(title):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in FT.key_to_index]
        list_[3] = [word for word in list_[3] if word in FT.key_to_index]
        list_[4] = [word for word in list_[4] if word in FT.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            # Check if lists are empty before calculating similarity
            if list1[2] and list2[2]:
                score_catg = FT.n_similarity(list1[2], list2[2])
            else:
                score_catg = 0  # or a suitable default value

            if list1[3] and list2[3]:
                score_desc = FT.n_similarity(list1[3], list2[3])
            else:
                score_desc = 0  # or a suitable default value

            try:
                if list1[4] and list2[4]:
                    score_title = FT.n_similarity(list1[4], list2[4]) / 2
                else:
                    score_title = 0
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )
    df_netflix_similarity["final_score"] = (
        df_netflix_similarity["score_title"]
        + df_netflix_similarity["score_category"]
        + df_netflix_similarity["score_description"]
    )
    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### Example 1 : Execution of recommendation function

# %%
recommendation("Grown Ups")
# Out:
# 100%|██████████| 8807/8807 [00:06<00:00, 1362.54it/s]
#                                recommendation      title  score_title  \
# 84                                 Fall Girls  Grown Ups     0.264962
# 75  Blue Mountain State: The Rise of Thadland  Grown Ups     0.255071
# 76            Bring It On: Worldwide Showdown  Grown Ups     0.260720
# 59                                  Wild Oats  Grown Ups     0.238926
# 91                               Little Nicky  Grown Ups     0.259115
# 58                               The Outcasts  Grown Ups     0.239393
# 73                                   Big Bear  Grown Ups     0.259489
# 53                         Father of the Year  Grown Ups     0.244703
# 70                Adventures in Public School  Grown Ups     0.250181
# 13                                   Bad Trip  Grown Ups     0.243564
#
#     score_category  score_description  final_score
# 84             1.0           0.908869     2.173830
# 75             1.0           0.913453     2.168524
# 76             1.0           0.901196     2.161916
# 59             1.0           0.921691     2.160617
# 91             1.0           0.900927     2.160042
# 58             1.0           0.920426     2.159819
# 73             1.0           0.898815     2.158304
# 53             1.0           0.912112     2.156815
# 70             1.0           0.905719     2.155899
# 13             1.0           0.911599     2.155163

# %%
movies_to_check = ['Grown Ups',
"Fall Girls",
'Blue Mountain State: The Rise of Thadland',
'Bring It On: Worldwide Showdown',
'Wild Oats',
"Little Nicky",
'The Outcasts',
'Big Bear',
'Father of the Year',
'Adventures in Public Schoo',
"Bad Trip"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                                      title   listed_in  \
# 27       s28                                  Grown Ups  [comedies]
# 1157   s1158                                   Bad Trip  [comedies]
# 4761   s4762                         Father of the Year  [comedies]
# 5328   s5329                               The Outcasts  [comedies]
# 5487   s5488                                  Wild Oats  [comedies]
# 6302   s6303                                   Big Bear  [comedies]
# 6340   s6341  Blue Mountain State: The Rise of Thadland  [comedies]
# 6377   s6378            Bring It On: Worldwide Showdown  [comedies]
# 6734   s6735                                 Fall Girls  [comedies]
# 7316   s7317                               Little Nicky  [comedies]
#
#                                             description  \
# 27    [beloved, basketball, coach, loss, their, and,...
# 1157  [people, comedy, real, pull, on, this, their, ...
# 4761  [win, debate, mayhem, whose, in, their, when, ...
# 5328  [hierarchy, turns, on, nerd, s, uprising, thei...
# 5487  [pal, canary, insurance, and, their, her, reti...
# 6302  [party, fiancée, jinks, illfated, s, new, when...
# 6340  [party, beloved, raunchiest, it, and, in, new,...
# 6377  [squad, on, cheer, in, new, teams, when, from,...
# 6734  [left, closing, it, try, their, in, following,...
# 7316  [dad, nicky, dear, back, from, oust, earth, so...
#
#                                              title_list
# 27                                         [grown, ups]
# 1157                                        [trip, bad]
# 4761                            [the, of, father, year]
# 5328                                    [the, outcasts]
# 5487                                       [wild, oats]
# 6302                                        [bear, big]
# 6340  [:, the, blue, state, of, rise, thadland, moun...
# 6377            [:, worldwide, on, bring, it, showdown]
# 6734                                      [girls, fall]
# 7316                                    [nicky, little]

# %% [markdown]
# ### Example 2 : Execution of recommendation function

# %%
recommendation("The Conjuring")
# Out:
# 100%|██████████| 8807/8807 [00:05<00:00, 1530.29it/s]
#                       recommendation          title  score_title  \
# 827                     The Darkness  The Conjuring     0.425480
# 202                    The Strangers  The Conjuring     0.428531
# 2474  House at the End of the Street  The Conjuring     0.412842
# 296                The Strange House  The Conjuring     0.417601
# 3012   The Haunting of Molly Hartley  The Conjuring     0.425382
# 1366                     The Silence  The Conjuring     0.412425
# 2988                The Devil Inside  The Conjuring     0.418330
# 2948                    The Basement  The Conjuring     0.413454
# 3073                      The Rezort  The Conjuring     0.447428
# 2976                       The Craft  The Conjuring     0.411635
#
#       score_category  score_description  final_score
# 827         1.000000           0.951606     2.377087
# 202         1.000000           0.946117     2.374648
# 2474        1.000000           0.951542     2.364383
# 296         0.987606           0.958616     2.363822
# 3012        1.000000           0.932987     2.358370
# 1366        1.000000           0.942992     2.355417
# 2988        1.000000           0.930568     2.348898
# 2948        1.000000           0.928820     2.342274
# 3073        0.963551           0.930551     2.341530
# 2976        1.000000           0.928963     2.340598

# %%
movies_to_check = ['The Conjuring',
"The Darkness",
'The Strangers',
'House at the End of the Street',
'The Strange House',
"The Haunting of Molly Hartley",
'The Silence',
'The Devil Inside',
'The Basemen',
'The Rezort',
"The Craf"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                           title  \
# 607     s608                   The Strangers
# 887     s888               The Strange House
# 1283   s1284                   The Conjuring
# 2382   s2383                    The Darkness
# 3930   s3931                     The Silence
# 7009   s7010  House at the End of the Street
# 8276   s8277                The Devil Inside
# 8338   s8339   The Haunting of Molly Hartley
# 8483   s8484                      The Rezort
#
#                                           listed_in  \
# 607                  [movies, thrillers, horror, ,]
# 887   [movies, thrillers, horror, ,, international]
# 1283                 [movies, thrillers, horror, ,]
# 2382                 [movies, thrillers, horror, ,]
# 3930                 [movies, thrillers, horror, ,]
# 7009                 [movies, thrillers, horror, ,]
# 8276                 [movies, thrillers, horror, ,]
# 8338                 [movies, thrillers, horror, ,]
# 8483             [movies, horror, international, ,]
#
#                                             description  \
# 607   [home, attack, three, when, quiet, vacation, b...
# 887   [home, brothers, moves, bigcity, try, and, the...
# 1283  [supernatural, noted, farmhouse, pair, demonol...
# 2382  [home, unleashes, begins, ancient, set, bringi...
# 3930  [deadly, creatures, attack, city, and, with, h...
# 7009  [she, new, when, was, house, site, town, more,...
# 8276  [people, this, s, and, her, behind, three, gri...
# 8338  [troubled, catch, with, new, her, but, start, ...
# 8483  [luxury, tourists, fails, hunted, on, global, ...
#
#                                title_list
# 607                      [strangers, the]
# 887                 [strange, the, house]
# 1283                     [conjuring, the]
# 2382                      [the, darkness]
# 3930                       [silence, the]
# 7009    [house, the, street, of, at, end]
# 8276                 [devil, the, inside]
# 8338  [the, hartley, molly, of, haunting]
# 8483                        [rezort, the]

# %% [markdown]
# # 6. Model 2 : Considering different weights for different features

# %% [markdown]
# ### Defining the recommendation function with different weights to be considered for different features

# %%
from tqdm import tqdm


def recommendation(title, weight_title=0.5, weight_category=1.0, weight_description=1.0):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in FT.key_to_index]
        list_[3] = [word for word in list_[3] if word in FT.key_to_index]
        list_[4] = [word for word in list_[4] if word in FT.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            # Check if lists are empty before calculating similarity
            if list1[2] and list2[2]:  # Ensure both lists are not empty
                score_catg = FT.n_similarity(list1[2], list2[2])
            else:
                score_catg = 0  # or a suitable default value

            if list1[3] and list2[3]:  # Ensure both lists are not empty
                score_desc = FT.n_similarity(list1[3], list2[3])
            else:
                score_desc = 0  # or a suitable default value

            try:
                if list1[4] and list2[4]:  # Ensure both lists are not empty
                    score_title = FT.n_similarity(list1[4], list2[4]) / 2
                else:
                    score_title = 0
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )
    df_netflix_similarity["final_score"] = (
        weight_title * df_netflix_similarity["score_title"]
        + weight_category * df_netflix_similarity["score_category"]
        + weight_description * df_netflix_similarity["score_description"]
    )
    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### example 1

# %%
recommendation("Grown Ups", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:06<00:00, 1458.47it/s]
#                                recommendation      title  score_title  \
# 88                         How to Be a Player  Grown Ups     0.212058
# 59                                  Wild Oats  Grown Ups     0.238926
# 58                               The Outcasts  Grown Ups     0.239393
# 75  Blue Mountain State: The Rise of Thadland  Grown Ups     0.255071
# 84                                 Fall Girls  Grown Ups     0.264962
# 53                         Father of the Year  Grown Ups     0.244703
# 13                                   Bad Trip  Grown Ups     0.243564
# 93                                  Mad Money  Grown Ups     0.234010
# 70                Adventures in Public School  Grown Ups     0.250181
# 63                                Take the 10  Grown Ups     0.231953
#
#     score_category  score_description  final_score
# 88             1.0           0.933468     2.010392
# 59             1.0           0.921691     2.009031
# 58             1.0           0.920426     2.008159
# 75             1.0           0.913453     2.007283
# 84             1.0           0.908869     2.006584
# 53             1.0           0.912112     2.003100
# 13             1.0           0.911599     2.002349
# 93             1.0           0.913897     2.001321
# 70             1.0           0.905719     1.999629
# 63             1.0           0.912374     1.999485

# %% [markdown]
# ### Example 2

# %%
recommendation("Jeans", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:06<00:00, 1353.48it/s]
#               recommendation  title  score_title  score_category  \
# 1080      Lock Your Girls In  Jeans     0.187516             1.0
# 2096  Tere Naal Love Ho Gaya  Jeans     0.169272             1.0
# 779         Ginny Weds Sunny  Jeans     0.208882             1.0
# 3297     Maza Pati Karodpati  Jeans     0.152755             1.0
# 1139            Rich in Love  Jeans     0.164621             1.0
# 1503         Brother in Love  Jeans     0.156901             1.0
# 3277                  Man Up  Jeans     0.164388             1.0
# 156              Flower Girl  Jeans     0.196663             1.0
# 557             Squared Love  Jeans     0.163682             1.0
# 1101               Zaki Chan  Jeans     0.131871             1.0
#
#       score_description  final_score
# 1080           0.947592     2.014328
# 2096           0.945369     2.007077
# 779            0.927564     2.004716
# 3297           0.945174     2.001965
# 1139           0.932938     1.995736
# 1503           0.934849     1.994950
# 3277           0.931239     1.994308
# 156            0.917342     1.992872
# 557            0.929007     1.992310
# 1101           0.940293     1.991796

# %% [markdown]
# # 7. Model 3 : Considering wider set of features with differentiated weighting
#
# Features considered for content based filtering are title , director , cast , country , genre(listed_in) , description
#
# basic weights are applied to different features to explain the possibility , generally weights are allocated in conjunction with the functional expert

# %% [markdown]
# ### Load the dataset

# %%
# Load data
df_netflix = pd.read_csv("netflix_titles.csv")

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Remove features not to be considered for recommendation engine

# %%
df_netflix.drop(
    columns=[
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title         director  \
# 0      s1  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2         Blood & Water              NaN
# 2      s3             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'listed_in',
#        'description'],
#       dtype='object')

# %% [markdown]
# ### Data preprocessing

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["director"] = df_netflix["director"].str.lower()
df_netflix["cast"] = df_netflix["cast"].str.lower()
df_netflix["country"] = df_netflix["country"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

# Fill NaN values with empty strings and convert lists to strings
for col in ["director", "cast", "country"]:
    df_netflix[col] = df_netflix[col].fillna('').astype(str).apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["director"] = df_netflix["director"].apply(word_tokenize)
df_netflix["cast"] = df_netflix["cast"].apply(word_tokenize)
df_netflix["country"] = df_netflix["country"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [kirsten, johnson]
# 1      s2         Blood & Water                  []
# 2      s3             Ganglands  [julien, leclercq]
#
#                                                 cast           country  \
# 0                                                 []  [united, states]
# 1  [ama, qamata, ,, khosi, ngema, ,, gail, mabala...   [south, africa]
# 2  [sami, bouajila, ,, tracy, gotoas, ,, samuel, ...                []
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["director"] = df_netflix["director"].apply(lambda x: list(set(x)))
df_netflix["cast"] = df_netflix["cast"].apply(lambda x: list(set(x)))
df_netflix["country"] = df_netflix["country"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(2)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [johnson, kirsten]
# 1      s2         Blood & Water                  []
#
#                                                 cast           country  \
# 0                                                 []  [states, united]
# 1  [morny, mahlangu, mabalane, qamata, odwa, sham...   [africa, south]
#
#                                           listed_in  \
# 0                                   [documentaries]
# 1  [mysteries, dramas, shows, ,, tv, international]
#
#                                          description  \
# 0  [johnson, kirsten, inventive, death, life, and...
# 1  [party, birth, her, sister, paths, swimming, w...
#
#                   title_list
# 0  [is, dick, johnson, dead]
# 1          [blood, water, &]

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in FT.key_to_index]
    list_[3] = [word for word in list_[3] if word in FT.key_to_index]
    list_[4] = [word for word in list_[4] if word in FT.key_to_index]
    list_[5] = [word for word in list_[5] if word in FT.key_to_index]
    list_[6] = [word for word in list_[6] if word in FT.key_to_index]
    list_[7] = [word for word in list_[7] if word in FT.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['johnson', 'kirsten']),
#        list([]), list(['states', 'united']), list(['documentaries']),
#        list(['johnson', 'kirsten', 'inventive', 'death', 'life', 'and', 'in', 'her', 'face', 'help', 'filmmaker', 'them', 'to', 'of', 'end', 'both', 'nears', 'comical', 'as', 'stages', 'the', 'father', 'inevitable', 'his', 'ways']),
#        list(['is', 'dick', 'johnson', 'dead'])], dtype=object)

# %% [markdown]
# ### Defining the recommendation engine function

# %%
def recommendation(title, weight_title=1.0, weight_director=1.0, weight_cast=1.0,
                   weight_country=1.0, weight_genre=1.0, weight_description=1.0):

    # Extract the selected movie's features based on title
    matrix_netflix_title_vocab = []
    target_movies = df_netflix[df_netflix["title"] == title]

    if target_movies.empty:
        print(f"'{title}' not found in the dataset.")
        return pd.DataFrame()

    for list_ in target_movies.to_numpy():
        list_[2] = [word for word in list_[2] if word in FT.key_to_index]
        list_[3] = [word for word in list_[3] if word in FT.key_to_index]
        list_[4] = [word for word in list_[4] if word in FT.key_to_index]
        list_[5] = [word for word in list_[5] if word in FT.key_to_index]
        list_[6] = [word for word in list_[6] if word in FT.key_to_index]
        list_[7] = [word for word in list_[7] if word in FT.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(df_netflix.to_numpy(), total=len(df_netflix))
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:

            # Calculate similarity scores for each feature, handling empty lists
            score_director = FT.n_similarity(list1[2], list2[2]) if list1[2] and list2[2] else 0  # Handle empty lists
            score_cast = FT.n_similarity(list1[3], list2[3]) if list1[3] and list2[3] else 0  # Handle empty lists
            score_country = FT.n_similarity(list1[4], list2[4]) if list1[4] and list2[4] else 0  # Handle empty lists
            score_catg = FT.n_similarity(list1[5], list2[5]) if list1[5] and list2[5] else 0  # Handle empty lists
            score_desc = FT.n_similarity(list1[6], list2[6]) if list1[6] and list2[6] else 0  # Handle empty lists

            # Handle title similarity calculation with try-except
            try:
                score_title = FT.n_similarity(list1[7], list2[7])
            except KeyError:
                score_title = 0

            # If the titles are different and genre similarity is significant
            if list1[1] != list2[1] and score_catg > 0.85:
                # Calculate the weighted final score
                final_score = (
                    weight_title * score_title +
                    weight_director * score_director +
                    weight_cast * score_cast +
                    weight_country * score_country +
                    weight_genre * score_catg +
                    weight_description * score_desc
                )

                # Append all relevant scores for the DataFrame
                matrix_similarity.append([list1[1], score_title, score_director, score_country, score_catg, score_desc, final_score])

    pbar.close()

    # Create DataFrame of recommendations and sort by final score
    df_netflix_similarity = pd.DataFrame(matrix_similarity, columns=["recommendation", "score_title" , "score_director" ,"score_country","score_genre" , "score_description" , "final_score"])
    return df_netflix_similarity.sort_values(by="final_score", ascending=False).head(10)

# %% [markdown]
# ### Example 1 : execution of the recommendation engine

# %%
recommendation("Jeans", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:07<00:00, 1208.08it/s]
#               recommendation  score_title  score_director  score_country  \
# 3614         Story of an Egg     0.248979        0.724073       1.000000
# 1402              Baby Dolls     0.423790        0.635492       1.000000
# 2066                 Pad Man     0.390950        0.696254       1.000000
# 2096  Tere Naal Love Ho Gaya     0.338545        0.626213       1.000000
# 1538                Watchman     0.139439        0.799672       1.000000
# 1310     Hum Aapke Hain Koun     0.305975        0.696254       1.000000
# 3632              Super Nani     0.308808        0.642367       1.000000
# 2533      X: Past Is Present     0.196331        0.735206       1.000000
# 713             One More Try     0.268944        0.921026       0.560115
# 2163          Running Shaadi     0.351045        0.568379       1.000000
#
#       score_genre  score_description  final_score
# 3614     1.000000           0.929319     3.689187
# 1402     1.000000           0.909741     3.655913
# 2066     0.974175           0.862578     3.655251
# 2096     1.000000           0.945369     3.631695
# 1538     0.959184           0.862650     3.616319
# 1310     0.949942           0.933632     3.608734
# 3632     0.959184           0.918380     3.583727
# 2533     0.937818           0.893038     3.576176
# 713      0.974175           0.919138     3.573227
# 2163     1.000000           0.909852     3.573179

# %%
movies_to_check = ['Jeans',
"Story of an Egg",
'Baby Dolls',
'Pad Man',
'Tere Naal Love Ho Gaya',
"Watchman",
'Hum Aapke Hain Koun',
'Super Nani',
'X: Past Is Present',
'One More Try',
"Running Shaadi"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                   title  \
# 24       s25                   Jeans
# 1735   s1736            One More Try
# 2957   s2958     Hum Aapke Hain Koun
# 3189   s3190              Baby Dolls
# 3537   s3538                Watchman
# 4693   s4694                 Pad Man
# 4735   s4736  Tere Naal Love Ho Gaya
# 4904   s4905          Running Shaadi
# 5837   s5838      X: Past Is Present
# 8098   s8099         Story of an Egg
# 8124   s8125              Super Nani
#
#                                                director  \
# 24                                        [shankar, s.]
# 1735                                 [s., ruel, bayani]
# 2957                             [r., barjatya, sooraj]
# 3189                              [arora, vijay, kumar]
# 3537                                    [vijay, a., l.]
# 4693                                        [r., balki]
# 4735                                   [mandeep, kumar]
# 4904                                        [amit, roy]
# 5837  [mukherjee, d., tiwari, menon, hemant, pratim,...
# 8098                                  [shetty, b., raj]
# 8124                                     [indra, kumar]
#
#                                                    cast        country  \
# 24    [bachchan, prashanth, aishwarya, lakshmi, sri,...        [india]
# 1735  [angelica, angel, vergara, gina, dingdong, dan...  [philippines]
# 2957  [lagoo, khan, bahl, anupam, nath, bindu, renuk...        [india]
# 3189  [nirmal, tania, gurnam, chahal, sonam, sukhwin...        [india]
# 3537  [g.v, suman, yogi, munishkanth, hegde, samyukt...        [india]
# 4693  [singh, subhash, suneel, chaturvedi, jyoti, ra...        [india]
# 4735  [kartar, tinnu, riteish, navin, jaykar, cheema...        [india]
# 4904  [amit, pannu, brijendra, pankaj, neeta, jha, k...        [india]
# 5837  [rajat, swara, radhika, pooja, ruparel, jha, a...        [india]
# 8098  [amrutha, b., usha, naik, bhandary, prakash, r...        [india]
# 8124  [rekha, joshi, randhir, rajesh, anupam, kumar,...        [india]
#
#                                             listed_in  \
# 24     [comedies, movies, romantic, ,, international]
# 1735     [movies, dramas, romantic, ,, international]
# 2957      [movies, dramas, classic, ,, international]
# 3189   [comedies, movies, romantic, ,, international]
# 3537     [comedies, movies, dramas, ,, international]
# 4693     [movies, dramas, romantic, ,, international]
# 4735   [comedies, movies, romantic, ,, international]
# 4904   [comedies, movies, romantic, ,, international]
# 5837  [movies, dramas, ,, independent, international]
# 8098   [comedies, movies, romantic, ,, international]
# 8124     [comedies, movies, dramas, ,, international]
#
#                                             description  \
# 24    [too, she, man, when, twin, convincing, marry,...
# 1735  [severe, on, s, their, with, her, reconnects, ...
# 2957  [falls, good, other, agrees, she, their, but, ...
# 3189  [their, with, mend, punjab, when, from, grandm...
# 3537  [shark, or, breaks, man, trouble, –, off, bung...
# 4693  [resistance, s, sanitary, and, entrepreneur, p...
# 4735  [works, been, she, s, man, suitor, and, her, w...
# 4904  [couples, help, daughter, former, to, of, a, r...
# 5837  [party, s, stranger, middleaged, when, meets, ...
# 8098  [or, obstacles, mate, face, when, being, to, o...
# 8124  [concerned, rescue, and, her, from, grandmothe...
#
#                         title_list
# 24                         [jeans]
# 1735              [try, more, one]
# 2957      [hum, koun, aapke, hain]
# 3189                 [dolls, baby]
# 3537                    [watchman]
# 4693                    [pad, man]
# 4735  [ho, love, tere, gaya, naal]
# 4904             [running, shaadi]
# 5837     [:, present, past, is, x]
# 8098          [egg, of, story, an]
# 8124                 [nani, super]

# %% [markdown]
# ### Example 2 : execution of the recommendation engine

# %%
recommendation("Dark", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:07<00:00, 1219.59it/s]
#       recommendation  score_title  score_director  score_country  score_genre  \
# 709      In The Dark     0.761273               0       0.683670     0.994008
# 1298      Black Spot     0.634470               0       0.785425     1.000000
# 712      Dark Desire     0.864873               0       0.402850     0.981370
# 2034        Spotless     0.506177               0       0.882893     1.000000
# 1910  Criminal Minds     0.506244               0       0.929293     0.983700
# 823      White Lines     0.605029               0       0.863576     0.965369
# 1834        The Mist     0.620031               0       0.929293     0.931463
# 834         The Eddy     0.504896               0       0.934140     0.970948
# 844        Reckoning     0.403519               0       0.943984     0.983700
# 2551   Ripper Street     0.475139               0       0.860319     0.985908
#
#       score_description  final_score
# 709            0.922426     3.138837
# 1298           0.879154     3.103439
# 712            0.925155     3.088954
# 2034           0.888883     3.082857
# 1910           0.913958     3.072230
# 823            0.879927     3.068910
# 1834           0.902659     3.067594
# 834            0.912671     3.060617
# 844            0.929391     3.059445
# 2551           0.914269     3.054307

# %%
movies_to_check = ['Dark',
"In The Dark",
'Black Spot',
'Dark Desire',
'Spotless',
"Criminal Minds",
'White Lines',
'The Mist',
'The Eddy',
'Reckoning',
"Ripper Street"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id           title  \
# 2229   s2230     In The Dark
# 2235   s2236     Dark Desire
# 2327   s2328            Dark
# 2530   s2531     White Lines
# 2553   s2554        The Eddy
# 2590   s2591       Reckoning
# 3746   s3747      Black Spot
# 5205   s5206        The Mist
# 5412   s5413  Criminal Minds
# 5752   s5753        Spotless
# 7870   s7871   Ripper Street
#
#                                                director  \
# 2229                                                 []
# 2235                                                 []
# 2327                                                 []
# 2530                                                 []
# 2553  [marrakchi, poul, alan, chazelle, laïla, houda...
# 2590                                                 []
# 3746                                                 []
# 5205                                                 []
# 5412                                                 []
# 5752                                                 []
# 7870                                                 []
#
#                                                    cast  \
# 2229  [casey, mpumlwana, krantz, sengbloh, morgan, s...
# 2235  [maite, carlos, huijara, hayser, regina, erik,...
# 2327  [maja, kampwirth, mendl, michael, anatole, seb...
# 2530  [belén, tom, fox, diego, laurence, nuno, casab...
# 2553  [elyes, stenberg, george, karyo, randy, biolay...
# 2590  [trammell, gloria, garayua, mitzi, finn, oxenb...
# 3746  [samuel, herzberg, jouy, tiphaine, naidra, rut...
# 5205  [sutherland, danica, butler, gus, luke, france...
# 5412  [kirsten, gray, hewitt, vangsness, lola, jeann...
# 5752  [marc-andré, brendan, lucy, denis, grondin, ga...
# 7870  [buring, macfadyen, rothenberg, clive, myanna,...
#
#                                             country  \
# 2229                               [states, united]
# 2235                                       [mexico]
# 2327                   [states, united, germany, ,]
# 2530                    [kingdom, spain, united, ,]
# 2553  [kingdom, germany, states, united, ,, france]
# 2590                 [australia, states, united, ,]
# 3746                           [france, belgium, ,]
# 5205                    [states, canada, united, ,]
# 5412                    [states, canada, united, ,]
# 5752                   [france, kingdom, united, ,]
# 7870                  [kingdom, ireland, united, ,]
#
#                                               listed_in  \
# 2229                      [dramas, shows, ,, tv, crime]
# 2235  [crime, shows, spanish-language, ,, tv, intern...
# 2327       [crime, dramas, shows, ,, tv, international]
# 2530      [international, shows, british, ,, tv, crime]
# 2553              [dramas, shows, ,, tv, international]
# 2590           [mysteries, dramas, shows, ,, tv, crime]
# 3746       [crime, dramas, shows, ,, tv, international]
# 5205                 [mysteries, dramas, horror, ,, tv]
# 5412           [mysteries, dramas, shows, ,, tv, crime]
# 5752       [crime, dramas, shows, ,, tv, international]
# 7870             [dramas, shows, british, ,, tv, crime]
#
#                                             description         title_list
# 2229  [turns, blind, in, her, with, when, best, vice...    [the, dark, in]
# 2235  [home, alma, and, in, her, fateful, weekend, f...     [desire, dark]
# 2327  [on, three, families, missing, generations, my...             [dark]
# 2530  [heads, she, life, s, quickly, in, down, behin...     [lines, white]
# 2553  [band, club, fights, protect, paris, and, with...        [the, eddy]
# 2590  [suburban, local, contend, on, their, in, with...        [reckoning]
# 3746  [crimes, edge, and, in, new, forest, grisly, e...      [spot, black]
# 5205  [stephen, creatures, on, it, s, new, by, based...        [the, mist]
# 5412  [fbi, getting, this, their, of, a, days, spend...  [minds, criminal]
# 5752  [mob, with, powerful, to, of, is, owner, a, cr...         [spotless]
# 7870  [ripper, been, london, it, s, jack, hopeful, a...   [ripper, street]
