# %% [markdown]
# # Building a Netflix recommender system leveraging node2vec
#
# Notebook Structure
#
# 1. Import necessary libraries
#
# 2. Import required dataset and perform baseline EDA
#
# 3. Model Development
#
# 4. Defining the recommender system and testing it

# %% [markdown]
# # 1. Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
! pip install node2vec
# Out:
# Collecting node2vec
#   Downloading node2vec-0.5.0-py3-none-any.whl.metadata (849 bytes)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.3.3)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.66.6)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (1.17.0)
# Downloading node2vec-0.5.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: node2vec
# Successfully installed node2vec-0.5.0

# %%
import networkx as nx  # create and store graph
from node2vec import Node2Vec  # To run node2vec algorithm

# %% [markdown]
# # 2. Import required dataset and perform baseline EDA

# %%
df_node2vec = pd.read_csv('netflix_titles.csv')

# %%
df_node2vec.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df_node2vec.shape
# Out:
# (8807, 12)

# %%
df_node2vec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_node2vec.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df_node2vec = df_node2vec.dropna()

# %%
df_node2vec.shape
# Out:
# (5332, 12)

# %%
df_node2vec[df_node2vec.title == "Dark"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df_node2vec.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df_node2vec.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...

# %%
df_node2vec.drop(
    columns=[
        "director",
        "cast",
        "country",
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)

# %%
df_node2vec.head(2)
# Out:
#   show_id                          title  \
# 7      s8                        Sankofa
# 8      s9  The Great British Baking Show
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...

# %% [markdown]
# # 3. Model Development

# %%
# function that will create edges for given movie title and its genres
def addToGraph(movie_name, graph):
    genres = (
        df_node2vec[df_node2vec["title"] == movie_name]["listed_in"]
        .values[0]
        .rstrip()
        .lower()
        .split(", ")
    )
    for genre in genres:
        graph.add_edge(movie_name.strip(), genre)
    return graph


# function that will create graph for all the movies name
def createGraph():
    graph = nx.Graph()
    for movie_name in df_node2vec["title"]:
        graph = addToGraph(movie_name, graph)
    return graph

# %%
graph = createGraph()

# %%
df_node2vec.head()
# Out:
#    show_id                          title  \
# 7       s8                        Sankofa
# 8       s9  The Great British Baking Show
# 9      s10                   The Starling
# 12     s13                   Je Suis Karl
# 24     s25                          Jeans
#
#                                            listed_in  \
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
# 24   Comedies, International Movies, Romantic Movies
#
#                                           description
# 7   On a photo shoot in Ghana, an American model s...
# 8   A talented batch of amateur bakers face off in...
# 9   A woman adjusting to life after a loss contend...
# 12  After most of her family is murdered in a terr...
# 24  When the father of the man she loves insists t...

# %%
# should be 2 since two genres are associated with it
print(graph.degree()["Norm of the North: King Sized Adventure"])
# should be 1 since 1 genres are associated with it
print(graph.degree()["#realityhigh"])
# Out:
# 2
# 1

# %%
df_node2vec[df_node2vec.title == "Norm of the North: King Sized Adventure"]
# Out:
#      show_id                                    title  \
# 7596   s7597  Norm of the North: King Sized Adventure
#
#                                listed_in  \
# 7596  Children & Family Movies, Comedies
#
#                                             description
# 7596  Before planning an awesome wedding for his gra...

# %%
df_node2vec[df_node2vec.title == "#realityhigh"]
# Out:
#      show_id         title listed_in  \
# 5277   s5278  #realityhigh  Comedies
#
#                                             description
# 5277  When nerdy high schooler Dani finally attracts...

# %%
node2vec = Node2Vec(graph, dimensions=20, walk_length=16, num_walks=10)
# Out:
# Computing transition probabilities:   0%|          | 0/5373 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 10/10 [01:04<00:00,  6.40s/it]

# %%
model = node2vec.fit(window=5, min_count=1)

# %%
model.wv.get_vector("The Conjuring")
# Out:
# array([-0.39057815, -0.05282983, -0.25896534,  0.5573635 , -0.27500632,
#         0.04780074, -0.31432876,  0.96265554, -1.0825372 ,  0.6146729 ,
#         0.6508771 , -0.50286454,  0.7377844 ,  0.29231125,  0.64863324,
#         0.85311836,  0.96137565,  0.77027947, -0.6244784 , -0.19032896],
#       dtype=float32)

# %%
len(model.wv.get_vector("The Conjuring"))
# Out:
# 20

# %%
model.wv.get_vector("Insidious")
# Out:
# array([-0.45415723, -0.12105472, -0.10463304,  0.5731137 , -0.26859346,
#         0.39746314, -0.4285761 ,  0.9007071 , -1.055953  ,  0.69204986,
#         0.6272208 , -0.49661463,  0.40043145,  0.3004164 ,  0.7750714 ,
#         0.818114  ,  0.9774349 ,  0.68617076, -0.61918545, -0.11619588],
#       dtype=float32)

# %%
model.wv.get_vector("Jeans")
# Out:
# array([-0.3293333 ,  0.484418  , -0.35894462, -0.29532745, -0.23164304,
#         0.18015042, -0.08787249,  0.93689215,  0.22192018,  0.3697792 ,
#         0.35850728, -0.7676775 ,  0.17584178, -0.39529833, -0.0882451 ,
#         0.21252935,  0.583652  , -0.30674177,  0.14374952,  0.35147154],
#       dtype=float32)

# %% [markdown]
# # 4. Defining the recommender system and testing it

# %%
# generate similar movies to given genre or title
def node2vec_recommender(name):
    for node, _ in model.wv.most_similar(name):
        print(node)

# %% [markdown]
# ### Example 1

# %%
node2vec_recommender("Insidious")
# Out:
# The Detained
# The Devil Inside
# The Ring
# Shelter
# The Vatican Tapes
# The Haunting of Molly Hartley
# Population 436
# Clinical
# House at the End of the Street
# The Charnel House

# %%
movies_to_check = ['Insidious' , 'The Detained' , 'The Devil Inside' , 'The Ring' , 'Shelter' , 'The Vatican Tapes' , 'The Haunting of Molly Hartley' , 'Population 436' , 'Clinical',
                      'House at the End of the Street' , 'The Charnel House']
df_node2vec[df_node2vec.title.isin(movies_to_check)]
# Out:
#      show_id                           title                 listed_in  \
# 804     s805                  Population 436  Horror Movies, Thrillers
# 1118   s1119                       Insidious  Horror Movies, Thrillers
# 5637   s5638                        Clinical  Horror Movies, Thrillers
# 7009   s7010  House at the End of the Street  Horror Movies, Thrillers
# 8001   s8002                         Shelter  Horror Movies, Thrillers
# 8242   s8243               The Charnel House  Horror Movies, Thrillers
# 8274   s8275                    The Detained  Horror Movies, Thrillers
# 8276   s8277                The Devil Inside  Horror Movies, Thrillers
# 8338   s8339   The Haunting of Molly Hartley  Horror Movies, Thrillers
# 8486   s8487                        The Ring  Horror Movies, Thrillers
# 8548   s8549               The Vatican Tapes  Horror Movies, Thrillers
#
#                                             description
# 804   A census taker sent to investigate why Rockwel...
# 1118  A family moves into a new home, where their so...
# 5637  A psychiatrist is plagued by flashbacks to a t...
# 7009  Moving to a new town proves even more stressfu...
# 8001  A forensic psychiatrist has to think outside t...
# 8242  After an architect transforms a slaughterhouse...
# 8274  Five high school students serving Saturday det...
# 8276  At once spooky and grisly, this thriller follo...
# 8338  A troubled teenage girl hopes to start fresh a...
# 8486  A reporter watches a video that supposedly set...
# 8548  A young woman hospitalized for an infected wou...

# %% [markdown]
# Good recommendation :
# "Insidious" is from the genre (Horror Movies, Thrillers) , the recommended movies are also from the same genre

# %% [markdown]
# ### Example 2

# %%
node2vec_recommender("The Conjuring")
# Out:
# Population 436
# Mara
# Unfriended
# In the Tall Grass
# The Charnel House
# The Ring
# Insidious
# Knock Knock
# The Vatican Tapes
# Havenhurst

# %%
movies_to_check = ['The Conjuring',
'Population 436',
'Mara',
'Unfriended',
'In the Tall Grass',
'The Charnel House',
'The Ring',
'Insidious',
'Knock Knock',
'The Vatican Tapes',
'Havenhurst']
df_node2vec[df_node2vec.title.isin(movies_to_check)]
# Out:
#      show_id              title                 listed_in  \
# 804     s805     Population 436  Horror Movies, Thrillers
# 1118   s1119          Insidious  Horror Movies, Thrillers
# 1283   s1284      The Conjuring  Horror Movies, Thrillers
# 1843   s1844         Unfriended  Horror Movies, Thrillers
# 3450   s3451  In the Tall Grass  Horror Movies, Thrillers
# 6942   s6943         Havenhurst  Horror Movies, Thrillers
# 7218   s7219        Knock Knock  Horror Movies, Thrillers
# 7402   s7403               Mara  Horror Movies, Thrillers
# 8242   s8243  The Charnel House  Horror Movies, Thrillers
# 8486   s8487           The Ring  Horror Movies, Thrillers
# 8548   s8549  The Vatican Tapes  Horror Movies, Thrillers
#
#                                             description
# 804   A census taker sent to investigate why Rockwel...
# 1118  A family moves into a new home, where their so...
# 1283  When a family starts experiencing supernatural...
# 1843  Six teens whose cyberbullying drove their clas...
# 3450  After hearing a boy's cry for help, a pregnant...
# 6942  An alcoholic with a tragic past rents an apart...
# 7218  A devoted husband and father on his own for th...
# 7402  When criminal psychologist Kate Fuller investi...
# 8242  After an architect transforms a slaughterhouse...
# 8486  A reporter watches a video that supposedly set...
# 8548  A young woman hospitalized for an infected wou...

# %% [markdown]
# Good recommendation :
# "The Conjuring" is from the genre (Horror Movies, Thrillers) , the recommended movies are also from the same genre

# %% [markdown]
# ### Example 3

# %%
node2vec_recommender("Jeans")
# Out:
# Romantik Komedi 2: Bekarlığa Veda
# Bewildered Bolbol
# You're My Boss
# 10 Days in Sun City
# Love, Rosie
# It's Her Day
# Eyyvah Eyyvah 2
# Don't Go Breaking My Heart 2
# Disconnect
# Man Up

# %%
movies_to_check = ['Jeans',
'Romantik Komedi 2: Bekarlığa Veda',
'Bewildered Bolbol',
"You're My Boss",
'10 Days in Sun City',
'Love, Rosie',
"It's Her Day",
'Eyyvah Eyyvah 2',
"Don't Go Breaking My Heart 2",
'Disconnect',
'Man Up']
df_node2vec[df_node2vec.title.isin(movies_to_check)]
# Out:
#      show_id                              title  \
# 24       s25                              Jeans
# 1216   s1217  Romantik Komedi 2: Bekarlığa Veda
# 1836   s1837                         Disconnect
# 2049   s2050                     You're My Boss
# 2195   s2196                       It's Her Day
# 3392   s3393                10 Days in Sun City
# 4338   s4339       Don't Go Breaking My Heart 2
# 6290   s6291                  Bewildered Bolbol
# 6726   s6727                    Eyyvah Eyyvah 2
# 7354   s7355                        Love, Rosie
# 7391   s7392                             Man Up
#
#                                             listed_in  \
# 24    Comedies, International Movies, Romantic Movies
# 1216  Comedies, International Movies, Romantic Movies
# 1836  Comedies, International Movies, Romantic Movies
# 2049  Comedies, International Movies, Romantic Movies
# 2195  Comedies, International Movies, Romantic Movies
# 3392  Comedies, International Movies, Romantic Movies
# 4338  Comedies, International Movies, Romantic Movies
# 6290  Comedies, International Movies, Romantic Movies
# 6726  Comedies, International Movies, Romantic Movies
# 7354  Comedies, International Movies, Romantic Movies
# 7391  Comedies, International Movies, Romantic Movies
#
#                                             description
# 24    When the father of the man she loves insists t...
# 1216  Didem tries everything to get actor Cem to pro...
# 1836  A group of singletons stumbles through the wil...
# 2049  Pong, a corporate assistant, poses as his comp...
# 2195  After a man promises his fiancé a dream weddin...
# 3392  After his girlfriend wins the Miss Nigeria pag...
# 4338  Zixin is about to marry Qihong, but her galliv...
# 6290  A man suffering from amnesia can't seem to cho...
# 6726  Hüseyin has found his father, and now has one ...
# 7354  Over the years, as they come and go in each ot...
# 7391  A single woman seizes an opportunity when, whi...

# %% [markdown]
# Good recommendation :
# "Jeans" is from the genre (Comedies, International Movies, Romantic Movies) , the recommended movies are also from the same genre

# %% [markdown]
# ### Example 4

# %%
node2vec_recommender("Sankofa")
# Out:
# Time Share
# A Heavy Heart
# El silencio es bienvenido
# La diosa del asfalto
# Ajeeb Daastaans
# Plaire, aimer et courir vite
# Jal
# Manu
# Komola Rocket
# 18 Presents

# %%
movies_to_check = ['Sankofa',
'Time Share',
'A Heavy Heart',
'El silencio es bienvenido',
'La diosa del asfalto',
'Ajeeb Daastaans',
'Plaire, aimer et courir vite',
'Jal',
'Manu',
'Komola Rocket',
'18 Presents']
df_node2vec[df_node2vec.title.isin(movies_to_check)]
# Out:
#      show_id                         title  \
# 7         s8                       Sankofa
# 282     s283          La diosa del asfalto
# 1023   s1024               Ajeeb Daastaans
# 2550   s2551                   18 Presents
# 2789   s2790     El silencio es bienvenido
# 3631   s3632                          Manu
# 4210   s4211                 Komola Rocket
# 4361   s4362                    Time Share
# 5600   s5601                 A Heavy Heart
# 7117   s7118                           Jal
# 7746   s7747  Plaire, aimer et courir vite
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 282   Dramas, Independent Movies, International Movies
# 1023  Dramas, Independent Movies, International Movies
# 2550  Dramas, Independent Movies, International Movies
# 2789  Dramas, Independent Movies, International Movies
# 3631  Dramas, Independent Movies, International Movies
# 4210  Dramas, Independent Movies, International Movies
# 4361  Dramas, Independent Movies, International Movies
# 5600  Dramas, Independent Movies, International Movies
# 7117  Dramas, Independent Movies, International Movies
# 7746  Dramas, Independent Movies, International Movies
#
#                                             description
# 7     On a photo shoot in Ghana, an American model s...
# 282   A woman from a tough neighborhood outside Mexi...
# 1023  Four shorts explore the surprising ways in whi...
# 2550  A pregnant mother with terminal cancer leaves ...
# 2789  As a teen languishes during a spiritless road ...
# 3631  The relationship between a painter and his adm...
# 4210  As the lives of rich and poor passengers aboar...
# 4361  Husband and father Pedro becomes increasingly ...
# 5600  Long past his heyday, a still-virile boxer tri...
# 7117  A gifted young man from a drought-stricken vil...
# 7746  When a Paris-based writer with AIDS meets a co...

# %% [markdown]
# Good recommendation :
# "Sankofa" is from the genre (Dramas, Independent Movies, International Movies) , the recommended movies are also from the same genre
