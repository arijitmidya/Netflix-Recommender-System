# %% [markdown]
# # Netflix Movies and TV shows Recommendation system
#
# Algorithm : Content Based Filtering - Glove for word embedding of text features
#
# Notebook summary
#
# 1. Import necessary libraries
#
# 2. Import required dataset
#
# 3. Data preprocessing for baseline model
#
# 4. Install necessary dependencies to leverage the Glove word embedding model from gensim
#
# 5. Model 1 ( baseline model ) : Considering equal weights for all features ( limited feature )
#
# 6. Model 2 : Considering different weights for different features
#
# 7. Model 3 : Considering wider set of features with differentiated weighting

# %% [markdown]
# # 1. Import necessary libraries

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Import required dataset

# %%
df_netflix = pd.read_csv("netflix_titles.csv")
df_netflix.drop(
    columns=[
        "director",
        "cast",
        "country",
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# # 3. Data preprocessing for baseline model

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, a, cape...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1   [,, shows, international, mysteries, dramas, tv]
# 2  [action, &, ,, shows, adventure, international...
#
#                                          description  \
# 0  [end, them, his, to, in, of, johnson, and, bot...
# 1  [swimming, out, to, star, birth, privateschool...
# 2  [deadly, robbers, his, to, and, of, a, war, dr...
#
#                   title_list
# 0  [is, dick, dead, johnson]
# 1          [water, blood, &]
# 2                [ganglands]

# %% [markdown]
# # 4. Install necessary dependencies to leverage the Glove word embedding model from gensim

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.17.0)

# %%
import gensim

# %%
import gensim.downloader as api

gv = api.load('glove-wiki-gigaword-300')
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in gv.key_to_index]
    list_[3] = [word for word in list_[3] if word in gv.key_to_index]
    list_[4] = [word for word in list_[4] if word in gv.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
len(matrix_netflix_vocab)
# Out:
# 8807

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['documentaries']),
#        list(['johnson', 'kirsten', 'inventive', 'death', 'life', 'and', 'in', 'her', 'face', 'help', 'filmmaker', 'them', 'to', 'of', 'end', 'both', 'nears', 'comical', 'as', 'stages', 'the', 'father', 'inevitable', 'his', 'ways']),
#        list(['is', 'dick', 'johnson', 'dead'])], dtype=object)

# %%
df_netflix_vocab.head(3)
# Out:
#   show_id                 title  \
# 0      s1  Dick Johnson Is Dead
# 1      s2         Blood & Water
# 2      s3             Ganglands
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1   [mysteries, dramas, shows, ,, tv, international]
# 2  [crime, adventure, shows, action, ,, tv, inter...
#
#                                          description  \
# 0  [johnson, kirsten, inventive, death, life, and...
# 1  [party, birth, her, sister, paths, swimming, w...
# 2  [deadly, protect, and, expert, from, powerful,...
#
#                   title_list
# 0  [is, dick, johnson, dead]
# 1          [blood, water, &]
# 2                         []

# %% [markdown]
# # 5. Model 1 ( baseline model ) :  Considering equal weights for all features ( limited feature )

# %% [markdown]
# ### Define the recommendation function

# %%
from tqdm import tqdm


def recommendation(title):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in gv.key_to_index]
        list_[3] = [word for word in list_[3] if word in gv.key_to_index]
        list_[4] = [word for word in list_[4] if word in gv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            # Check if lists are empty before calculating similarity
            if list1[2] and list2[2]:
                score_catg = gv.n_similarity(list1[2], list2[2])
            else:
                score_catg = 0  # or a suitable default value

            if list1[3] and list2[3]:
                score_desc = gv.n_similarity(list1[3], list2[3])
            else:
                score_desc = 0  # or a suitable default value

            try:
                if list1[4] and list2[4]:
                    score_title = gv.n_similarity(list1[4], list2[4]) / 2
                else:
                    score_title = 0
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )
    df_netflix_similarity["final_score"] = (
        df_netflix_similarity["score_title"]
        + df_netflix_similarity["score_category"]
        + df_netflix_similarity["score_description"]
    )
    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### Example 1 : Execution of recommendation function

# %%
recommendation("Grown Ups")
# Out:
# 100%|██████████| 8807/8807 [00:04<00:00, 1829.11it/s]
#                       recommendation      title  score_title  score_category  \
# 36      American Pie 9: Girls' Rules  Grown Ups     0.179184             1.0
# 39                           Work It  Grown Ups     0.188743             1.0
# 116               How to Be a Player  Grown Ups     0.190303             1.0
# 103  Bring It On: Worldwide Showdown  Grown Ups     0.200693             1.0
# 73                Father of the Year  Grown Ups     0.187940             1.0
# 27                      Mean Girls 2  Grown Ups     0.171069             1.0
# 138          The Bad Education Movie  Grown Ups     0.188562             1.0
# 112                       Fall Girls  Grown Ups     0.189624             1.0
# 94              A Bad Moms Christmas  Grown Ups     0.212740             1.0
# 144  The Goods: Live Hard, Sell Hard  Grown Ups     0.223016             1.0
#
#      score_description  final_score
# 36            0.875891     2.055075
# 39            0.859949     2.048693
# 116           0.851863     2.042166
# 103           0.829971     2.030664
# 73            0.842052     2.029992
# 27            0.856893     2.027962
# 138           0.838282     2.026843
# 112           0.835608     2.025232
# 94            0.808177     2.020917
# 144           0.793356     2.016372

# %%
movies_to_check = ['Grown Ups',
"American Pie 9: Girls' Rules",
'Work It',
'How to Be a Player',
'Bring It On: Worldwide Showdown',
"Father of the Year",
'Mean Girls 2',
'The Bad Education Movie',
'Fall Girls',
'A Bad Moms Christmas',
"The Goods: Live Hard, Sell Hard"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                            title   listed_in  \
# 27       s28                        Grown Ups  [comedies]
# 1459   s1460                     Mean Girls 2  [comedies]
# 1881   s1882     American Pie 9: Girls' Rules  [comedies]
# 2159   s2160                          Work It  [comedies]
# 4761   s4762               Father of the Year  [comedies]
# 6027   s6028             A Bad Moms Christmas  [comedies]
# 6377   s6378  Bring It On: Worldwide Showdown  [comedies]
# 6734   s6735                       Fall Girls  [comedies]
# 7015   s7016               How to Be a Player  [comedies]
# 8201   s8202          The Bad Education Movie  [comedies]
# 8325   s8326  The Goods: Live Hard, Sell Hard  [comedies]
#
#                                             description  \
# 27    [beloved, basketball, coach, loss, their, and,...
# 1459  [if, pariah, she, through, s, with, student, d...
# 1881  [around, seniors, muddles, their, new, student...
# 2159  [’, squad, s, and, her, senior, but, clumsy, b...
# 4761  [win, debate, mayhem, whose, in, their, when, ...
# 6027  [and, their, carla, looming, amy, back, when, ...
# 6377  [squad, on, cheer, in, new, teams, when, from,...
# 6734  [left, closing, it, try, their, in, following,...
# 7015  [life, and, sister, philandering, to, woman, o...
# 8201  [class, britain, s, and, trip, but, –, caring,...
# 8325  [sale, dealership, closer, local, on, rescue, ...
#
#                                    title_list
# 27                               [grown, ups]
# 1459                         [mean, girls, 2]
# 1881   [:, american, rules, pie, girls, ', 9]
# 2159                               [it, work]
# 4761                  [the, of, father, year]
# 6027                [christmas, a, moms, bad]
# 6377  [:, worldwide, on, bring, it, showdown]
# 6734                            [girls, fall]
# 7015                 [player, be, to, a, how]
# 8201             [the, movie, education, bad]
# 8325     [the, :, live, sell, goods, hard, ,]

# %% [markdown]
# ### Example 2 : Execution of recommendation function

# %%
recommendation("The Conjuring")
# Out:
# 100%|██████████| 8807/8807 [00:04<00:00, 1945.49it/s]
#                      recommendation          title  score_title  \
# 136                    The Darkness  The Conjuring     0.254167
# 466   The Haunting of Molly Hartley  The Conjuring     0.269575
# 379  House at the End of the Street  The Conjuring     0.248824
# 78                  The Conjuring 2  The Conjuring     0.375097
# 33                    The Strangers  The Conjuring     0.255073
# 342                Conjuring Spirit  The Conjuring     0.323950
# 52                The Strange House  The Conjuring     0.268225
# 265                      The Ritual  The Conjuring     0.285342
# 456                The Devil Inside  The Conjuring     0.252811
# 123          We Summon the Darkness  The Conjuring     0.258835
#
#      score_category  score_description  final_score
# 136        1.000000           0.902806     2.156973
# 466        1.000000           0.887063     2.156638
# 379        1.000000           0.906028     2.154853
# 78         0.921947           0.846441     2.143485
# 33         1.000000           0.883061     2.138134
# 342        0.937428           0.871832     2.133210
# 52         0.937428           0.918477     2.124130
# 265        0.937428           0.897559     2.120329
# 456        1.000000           0.866727     2.119538
# 123        1.000000           0.853419     2.112254

# %%
movies_to_check = ['The Conjuring',
"The Darkness",
'The Haunting of Molly Hartley',
'House at the End of the Street',
'The Conjuring 2',
"The Strangers",
'Conjuring Spirit',
'The Strange House',
'The Ritual',
'The Devil Inside',
"We Summon the Darkness"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                           title  \
# 607     s608                   The Strangers
# 887     s888               The Strange House
# 1283   s1284                   The Conjuring
# 1284   s1285                 The Conjuring 2
# 2149   s2150          We Summon the Darkness
# 2382   s2383                    The Darkness
# 5042   s5043                      The Ritual
# 6527   s6528                Conjuring Spirit
# 7009   s7010  House at the End of the Street
# 8276   s8277                The Devil Inside
# 8338   s8339   The Haunting of Molly Hartley
#
#                                           listed_in  \
# 607                  [movies, thrillers, horror, ,]
# 887   [movies, thrillers, horror, ,, international]
# 1283                 [movies, thrillers, horror, ,]
# 1284                               [movies, horror]
# 2149                 [movies, thrillers, horror, ,]
# 2382                 [movies, thrillers, horror, ,]
# 5042  [movies, thrillers, horror, ,, international]
# 6527  [movies, thrillers, horror, ,, international]
# 7009                 [movies, thrillers, horror, ,]
# 8276                 [movies, thrillers, horror, ,]
# 8338                 [movies, thrillers, horror, ,]
#
#                                             description  \
# 607   [home, attack, three, when, quiet, vacation, b...
# 887   [home, brothers, moves, bigcity, try, and, the...
# 1283  [supernatural, noted, farmhouse, pair, demonol...
# 1284  [confront, releases, spirit, enlists, london, ...
# 2149  [themselves, in, new, when, hits, concert, gri...
# 2382  [home, unleashes, begins, ancient, set, bringi...
# 5042  [with, trip, but, from, –, take, strained, wil...
# 6527  [spirit, moves, novelist, she, s, and, in, her...
# 7009  [she, new, when, was, house, site, town, more,...
# 8276  [people, this, s, and, her, behind, three, gri...
# 8338  [troubled, catch, with, new, her, but, start, ...
#
#                                title_list
# 607                      [strangers, the]
# 887                 [strange, the, house]
# 1283                     [conjuring, the]
# 1284                  [conjuring, the, 2]
# 2149          [we, summon, darkness, the]
# 2382                      [the, darkness]
# 5042                        [the, ritual]
# 6527                  [conjuring, spirit]
# 7009    [house, the, street, of, at, end]
# 8276                 [devil, the, inside]
# 8338  [the, hartley, molly, of, haunting]

# %% [markdown]
# # 6. Model 2 : Considering different weights for different features

# %% [markdown]
# ### Defining the recommendation function with different weights to be considered for different features

# %%
from tqdm import tqdm


def recommendation(title, weight_title=0.5, weight_category=1.0, weight_description=1.0):
    matrix_netflix_title_vocab = []
    for list_ in df_netflix[df_netflix["title"] == title].to_numpy():
        list_[2] = [word for word in list_[2] if word in gv.key_to_index]
        list_[3] = [word for word in list_[3] if word in gv.key_to_index]
        list_[4] = [word for word in list_[4] if word in gv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(matrix_netflix_vocab)
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:
            # Check if lists are empty before calculating similarity
            if list1[2] and list2[2]:  # Ensure both lists are not empty
                score_catg = gv.n_similarity(list1[2], list2[2])
            else:
                score_catg = 0  # or a suitable default value

            if list1[3] and list2[3]:  # Ensure both lists are not empty
                score_desc = gv.n_similarity(list1[3], list2[3])
            else:
                score_desc = 0  # or a suitable default value

            try:
                if list1[4] and list2[4]:  # Ensure both lists are not empty
                    score_title = gv.n_similarity(list1[4], list2[4]) / 2
                else:
                    score_title = 0
            except:
                score_title = 0
            if (list1[1] != list2[1]) & (score_catg > 0.85):
                matrix_similarity.append(
                    [list1[1], list2[1], score_title, score_catg, score_desc]
                )
        pbar.update()
    pbar.close()
    df_netflix_similarity = pd.DataFrame(
        matrix_similarity,
        columns=[
            "recommendation",
            "title",
            "score_title",
            "score_category",
            "score_description",
        ],
    )
    df_netflix_similarity["final_score"] = (
        weight_title * df_netflix_similarity["score_title"]
        + weight_category * df_netflix_similarity["score_category"]
        + weight_description * df_netflix_similarity["score_description"]
    )
    return df_netflix_similarity.sort_values(
        by=["final_score", "score_category", "score_description", "score_title"],
        ascending=False,
    ).head(10)

# %% [markdown]
# ### example 1

# %%
recommendation("Grown Ups", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:04<00:00, 2013.70it/s]
#                               recommendation      title  score_title  \
# 36              American Pie 9: Girls' Rules  Grown Ups     0.179184
# 39                                   Work It  Grown Ups     0.188743
# 116                       How to Be a Player  Grown Ups     0.190303
# 27                              Mean Girls 2  Grown Ups     0.171069
# 73                        Father of the Year  Grown Ups     0.187940
# 111  Dumb and Dumberer: When Harry Met Lloyd  Grown Ups     0.163759
# 138                  The Bad Education Movie  Grown Ups     0.188562
# 112                               Fall Girls  Grown Ups     0.189624
# 103          Bring It On: Worldwide Showdown  Grown Ups     0.200693
# 21                                  Bad Trip  Grown Ups     0.173631
#
#      score_category  score_description  final_score
# 36              1.0           0.875891     1.954468
# 39              1.0           0.859949     1.944583
# 116             1.0           0.851863     1.938582
# 27              1.0           0.856893     1.936835
# 73              1.0           0.842052     1.930024
# 111             1.0           0.849449     1.928687
# 138             1.0           0.838282     1.927194
# 112             1.0           0.835608     1.925374
# 103             1.0           0.829971     1.924185
# 21              1.0           0.835535     1.920517

# %% [markdown]
# ### Example 2

# %%
recommendation("Jeans", weight_title=0.3, weight_category=1.2, weight_description=0.8)
# Out:
# 100%|██████████| 8807/8807 [00:05<00:00, 1701.72it/s]
#                    recommendation  title  score_title  score_category  \
# 793            Lock Your Girls In  Jeans     0.121569             1.0
# 837                  Rich in Love  Jeans     0.072769             1.0
# 101                   Flower Girl  Jeans     0.109514             1.0
# 562            A Chaster Marriage  Jeans     0.045104             1.0
# 2727              We Need to Talk  Jeans     0.060617             1.0
# 569               You've Got This  Jeans     0.082126             1.0
# 195   Kambili: The Whole 30 Yards  Jeans     0.043745             1.0
# 769                  Mr. Romantic  Jeans     0.073811             1.0
# 798           The Married Couples  Jeans     0.054506             1.0
# 817            I love you, stupid  Jeans     0.105102             1.0
#
#       score_description  final_score
# 793            0.917724     1.970650
# 837            0.924072     1.961088
# 101            0.904719     1.956629
# 562            0.926697     1.954889
# 2727           0.919157     1.953511
# 569            0.909601     1.952318
# 195            0.918973     1.948302
# 769            0.907146     1.947860
# 798            0.907658     1.942479
# 817            0.888149     1.942050

# %% [markdown]
# # 7. Model 3 : Considering wider set of features with differentiated weighting
#
# Features considered for content based filtering are title , director , cast , country , genre(listed_in) , description
#
# basic weights are applied to different features to explain the possibility , generally weights are allocated in conjunction with the functional expert

# %% [markdown]
# ### Load the dataset

# %%
# Load data
df_netflix = pd.read_csv("netflix_titles.csv")

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Remove features not to be considered for recommendation engine

# %%
df_netflix.drop(
    columns=[
        "date_added",
        "release_year",
        "rating",
        "duration",
        "type",
    ],
    inplace=True,
)
df_netflix.head(3)
# Out:
#   show_id                 title         director  \
# 0      s1  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2         Blood & Water              NaN
# 2      s3             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'listed_in',
#        'description'],
#       dtype='object')

# %% [markdown]
# ### Data preprocessing

# %%
from nltk.tokenize import word_tokenize

df_netflix["title_list"] = df_netflix["title"].str.lower()
df_netflix["director"] = df_netflix["director"].str.lower()
df_netflix["cast"] = df_netflix["cast"].str.lower()
df_netflix["country"] = df_netflix["country"].str.lower()
df_netflix["listed_in"] = df_netflix["listed_in"].str.lower()
df_netflix["description"] = df_netflix["description"].str.lower()

# Fill NaN values with empty strings and convert lists to strings
for col in ["director", "cast", "country"]:
    df_netflix[col] = df_netflix[col].fillna('').astype(str).apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

df_netflix["title_list"] = df_netflix["title_list"].apply(word_tokenize)
df_netflix["director"] = df_netflix["director"].apply(word_tokenize)
df_netflix["cast"] = df_netflix["cast"].apply(word_tokenize)
df_netflix["country"] = df_netflix["country"].apply(word_tokenize)
df_netflix["listed_in"] = df_netflix["listed_in"].apply(word_tokenize)
df_netflix["description"] = df_netflix["description"].apply(word_tokenize)

# %%
df_netflix.head(3)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [kirsten, johnson]
# 1      s2         Blood & Water                  []
# 2      s3             Ganglands  [julien, leclercq]
#
#                                                 cast           country  \
# 0                                                 []  [united, states]
# 1  [ama, qamata, ,, khosi, ngema, ,, gail, mabala...   [south, africa]
# 2  [sami, bouajila, ,, tracy, gotoas, ,, samuel, ...                []
#
#                                            listed_in  \
# 0                                    [documentaries]
# 1  [international, tv, shows, ,, tv, dramas, ,, t...
# 2  [crime, tv, shows, ,, international, tv, shows...
#
#                                          description  \
# 0  [as, her, father, nears, the, end, of, his, li...
# 1  [after, crossing, paths, at, a, party, ,, a, c...
# 2  [to, protect, his, family, from, a, powerful, ...
#
#                   title_list
# 0  [dick, johnson, is, dead]
# 1          [blood, &, water]
# 2                [ganglands]

# %%
import string

df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word.translate(str.maketrans("", "", string.punctuation)) for word in x]
)
df_netflix["description"] = df_netflix["description"].apply(
    lambda x: [word for word in x if len(word) > 0]
)

# %%
df_netflix["title_list"] = df_netflix["title_list"].apply(lambda x: list(set(x)))
df_netflix["director"] = df_netflix["director"].apply(lambda x: list(set(x)))
df_netflix["cast"] = df_netflix["cast"].apply(lambda x: list(set(x)))
df_netflix["country"] = df_netflix["country"].apply(lambda x: list(set(x)))
df_netflix["listed_in"] = df_netflix["listed_in"].apply(lambda x: list(set(x)))
df_netflix["description"] = df_netflix["description"].apply(lambda x: list(set(x)))

# %%
df_netflix.head(2)
# Out:
#   show_id                 title            director  \
# 0      s1  Dick Johnson Is Dead  [johnson, kirsten]
# 1      s2         Blood & Water                  []
#
#                                                 cast           country  \
# 0                                                 []  [states, united]
# 1  [morny, mahlangu, mabalane, qamata, odwa, sham...   [africa, south]
#
#                                           listed_in  \
# 0                                   [documentaries]
# 1  [mysteries, dramas, shows, ,, tv, international]
#
#                                          description  \
# 0  [johnson, kirsten, inventive, death, life, and...
# 1  [party, birth, her, sister, paths, swimming, w...
#
#                   title_list
# 0  [is, dick, johnson, dead]
# 1          [blood, water, &]

# %%
matrix_netflix_vocab = []
for list_ in df_netflix.to_numpy():
    list_[2] = [word for word in list_[2] if word in gv.key_to_index]
    list_[3] = [word for word in list_[3] if word in gv.key_to_index]
    list_[4] = [word for word in list_[4] if word in gv.key_to_index]
    list_[5] = [word for word in list_[5] if word in gv.key_to_index]
    list_[6] = [word for word in list_[6] if word in gv.key_to_index]
    list_[7] = [word for word in list_[7] if word in gv.key_to_index]
    matrix_netflix_vocab.append(list_)
df_netflix_vocab = pd.DataFrame(matrix_netflix_vocab, columns=df_netflix.columns)

# %%
matrix_netflix_vocab[0]
# Out:
# array(['s1', 'Dick Johnson Is Dead', list(['johnson', 'kirsten']),
#        list([]), list(['states', 'united']), list(['documentaries']),
#        list(['johnson', 'kirsten', 'inventive', 'death', 'life', 'and', 'in', 'her', 'face', 'help', 'filmmaker', 'them', 'to', 'of', 'end', 'both', 'nears', 'comical', 'as', 'stages', 'the', 'father', 'inevitable', 'his', 'ways']),
#        list(['is', 'dick', 'johnson', 'dead'])], dtype=object)

# %% [markdown]
# ### Defining the recommendation engine function

# %%
def recommendation(title, weight_title=1.0, weight_director=1.0, weight_cast=1.0,
                   weight_country=1.0, weight_genre=1.0, weight_description=1.0):

    # Extract the selected movie's features based on title
    matrix_netflix_title_vocab = []
    target_movies = df_netflix[df_netflix["title"] == title]

    if target_movies.empty:
        print(f"'{title}' not found in the dataset.")
        return pd.DataFrame()

    for list_ in target_movies.to_numpy():
        list_[2] = [word for word in list_[2] if word in gv.key_to_index]
        list_[3] = [word for word in list_[3] if word in gv.key_to_index]
        list_[4] = [word for word in list_[4] if word in gv.key_to_index]
        list_[5] = [word for word in list_[5] if word in gv.key_to_index]
        list_[6] = [word for word in list_[6] if word in gv.key_to_index]
        list_[7] = [word for word in list_[7] if word in gv.key_to_index]
        matrix_netflix_title_vocab.append(list_)

    matrix_similarity = []
    pbar = tqdm(df_netflix.to_numpy(), total=len(df_netflix))
    for list1 in pbar:
        for list2 in matrix_netflix_title_vocab:

            # Calculate similarity scores for each feature, handling empty lists
            score_director = gv.n_similarity(list1[2], list2[2]) if list1[2] and list2[2] else 0  # Handle empty lists
            score_cast = gv.n_similarity(list1[3], list2[3]) if list1[3] and list2[3] else 0  # Handle empty lists
            score_country = gv.n_similarity(list1[4], list2[4]) if list1[4] and list2[4] else 0  # Handle empty lists
            score_catg = gv.n_similarity(list1[5], list2[5]) if list1[5] and list2[5] else 0  # Handle empty lists
            score_desc = gv.n_similarity(list1[6], list2[6]) if list1[6] and list2[6] else 0  # Handle empty lists

            # Handle title similarity calculation with try-except
            try:
                score_title = gv.n_similarity(list1[7], list2[7])
            except KeyError:
                score_title = 0

            # If the titles are different and genre similarity is significant
            if list1[1] != list2[1] and score_catg > 0.85:
                # Calculate the weighted final score
                final_score = (
                    weight_title * score_title +
                    weight_director * score_director +
                    weight_cast * score_cast +
                    weight_country * score_country +
                    weight_genre * score_catg +
                    weight_description * score_desc
                )

                # Append all relevant scores for the DataFrame
                matrix_similarity.append([list1[1], score_title, score_director, score_country, score_catg, score_desc, final_score])

    pbar.close()

    # Create DataFrame of recommendations and sort by final score
    df_netflix_similarity = pd.DataFrame(matrix_similarity, columns=["recommendation", "score_title" , "score_director" ,"score_country","score_genre" , "score_description" , "final_score"])
    return df_netflix_similarity.sort_values(by="final_score", ascending=False).head(10)

# %% [markdown]
# ### Example 1 : execution of the recommendation engine

# %%
recommendation("Jeans", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:08<00:00, 1004.70it/s]
#                     recommendation  score_title  score_director  \
# 1120                      Oh! Baby     0.209470        0.547239
# 2562               Story of an Egg     0.012047        0.473245
# 1542                           Mom     0.265060        0.531270
# 957                     Thottappan     0.000000        0.571753
# 1500  Luv Shuv Tey Chicken Khurana     0.123488        0.494641
# 1055           Evvarikee Cheppoddu     0.000000        0.581202
# 2242                Ishqedarriyaan     0.000000        0.618009
# 1835                          Pink     0.352745        0.389992
# 1649                          Guru     0.024545        0.439359
# 993                         Aaviri     0.000000        0.547487
#
#       score_country  score_genre  score_description  final_score
# 1120            1.0     0.890147           0.868717     3.218636
# 2562            1.0     1.000000           0.902408     3.123998
# 1542            1.0     0.886717           0.876154     3.107324
# 957             1.0     0.943261           0.894483     3.052695
# 1500            1.0     1.000000           0.764547     3.048975
# 1055            1.0     1.000000           0.881492     3.045599
# 2242            1.0     0.969476           0.918113     3.044096
# 1835            1.0     0.909108           0.798607     3.043638
# 1649            1.0     0.909108           0.839286     3.033859
# 993             1.0     0.855623           0.889050     3.031763

# %%
movies_to_check = ['Jeans',
"Oh! Baby",
'Story of an Egg',
'Mom',
'Thottappan',
"Luv Shuv Tey Chicken Khurana",
'Evvarikee Cheppoddu',
'Ishqedarriyaan',
'Pink',
'Guru',
"Aaviri"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                         title                     director  \
# 24       s25                         Jeans                [shankar, s.]
# 2935   s2936                    Thottappan    [shanavas, bavakutty, k.]
# 3077   s3078                        Aaviri                 [babu, ravi]
# 3224   s3225           Evvarikee Cheppoddu     [shankar, eeday, basava]
# 3516   s3517                      Oh! Baby     [v., b., reddy, nandini]
# 4582   s4583  Luv Shuv Tey Chicken Khurana             [sharma, sameer]
# 4692   s4693                           Mom              [udyawar, ravi]
# 5008   s5009                          Guru               [ratnam, mani]
# 5629   s5630                          Pink  [chowdhury, roy, aniruddha]
# 7099   s7100                Ishqedarriyaan            [prakash, v., k.]
# 8098   s8099               Story of an Egg            [shetty, b., raj]
#
#                                                    cast  country  \
# 24    [bachchan, prashanth, aishwarya, lakshmi, sri,...  [india]
# 2935  [dileesh, roshan, lal, k., sunitha, krishnan, ...  [india]
# 3077  [shankar, muktha, neha, khan, bharani, sri, ra...  [india]
# 3224  [ghani, p, vamsi, raj, k, prasanna, nekkanti, ...  [india]
# 3516  [ruth, sajja, jagapathi, babu, aishwarya, laks...  [india]
# 4582  [rajesh, tangri, bagga, dolly, munish, vinod, ...  [india]
# 4692  [singh, vikas, sajal, sridevi, siddiqui, adnan...  [india]
# 5008  [roshan, abhishek, mithun, balan, dhritiman, b...  [india]
# 5629  [pannu, bedi, dhritiman, kulhari, bachchan, pa...  [india]
# 7099  [evelyn, suhasini, mulay, dave, ,, kavin, sharma]  [india]
# 8098  [amrutha, b., usha, naik, bhandary, prakash, r...  [india]
#
#                                               listed_in  \
# 24       [comedies, movies, romantic, ,, international]
# 2935       [comedies, movies, dramas, ,, international]
# 3077      [movies, thrillers, horror, ,, international]
# 3224     [comedies, movies, romantic, ,, international]
# 3516  [comedies, movies, musicals, ,, music, interna...
# 4582     [comedies, movies, romantic, ,, international]
# 4692      [thrillers, movies, dramas, ,, international]
# 5008                 [dramas, movies, international, ,]
# 5629                 [dramas, movies, international, ,]
# 7099       [movies, dramas, romantic, ,, international]
# 8098     [comedies, movies, romantic, ,, international]
#
#                                             description  \
# 24    [too, she, man, when, twin, convincing, marry,...
# 2935  [partner, ’, left, life, s, himself, in, behin...
# 3077  [home, spirit, moves, their, in, daughter, eer...
# 3224  [wrench, otherwise, ’, s, their, when, must, t...
# 3516  [life, her, snapped, off, another, after, magi...
# 4582  [native, omi, london, himself, in, lawyer, ret...
# 4692  [party, furious, destroy, sexually, her, free,...
# 5008  [desai, ambitious, father, turkey, village, le...
# 5629  [assault, rape, s, lawyer, her, retired, attem...
# 7099  [happy, if, do, it, her, someone, willing, hel...
# 8098  [or, obstacles, mate, face, when, being, to, o...
#
#                               title_list
# 24                               [jeans]
# 2935                        [thottappan]
# 3077                            [aaviri]
# 3224              [cheppoddu, evvarikee]
# 3516                       [!, oh, baby]
# 4582  [chicken, shuv, khurana, tey, luv]
# 4692                               [mom]
# 5008                              [guru]
# 5629                              [pink]
# 7099                    [ishqedarriyaan]
# 8098                [egg, of, story, an]

# %% [markdown]
# ### Example 2 : execution of the recommendation engine

# %%
recommendation("Dark", weight_title=0.5, weight_director=1.0,
                                 weight_cast=0.8, weight_country=0.3,
                                 weight_genre=1.2, weight_description=0.7)
# Out:
# 100%|██████████| 8807/8807 [00:08<00:00, 979.12it/s]
#                           recommendation  score_title  score_director  \
# 533                          In The Dark     0.722748               0
# 984                           Black Spot     0.577885               0
# 518                             The Rain     0.368472               0
# 1185                      Dogs of Berlin     0.293526               0
# 1134                  Black Earth Rising     0.572252               0
# 1917                NSU German History X     0.190514               0
# 816                      Holiday Secrets     0.301575               0
# 911   13 Reasons Why: Beyond the Reasons     0.343255               0
# 2043                            The Fear     0.362412               0
# 1585                           Old Money     0.210149               0
#
#       score_country  score_genre  score_description  final_score
# 533        0.911336     0.959080           0.829338     2.734899
# 984        0.684016     1.000000           0.764338     2.718938
# 518        0.942079     0.940377           0.891177     2.687038
# 1185       0.736394     1.000000           0.831437     2.678881
# 1134       0.806567     0.932584           0.769729     2.669526
# 1917       0.736394     1.000000           0.783561     2.669373
# 816        0.736394     0.967966           0.822792     2.652093
# 911        0.911336     0.941553           0.793940     2.642866
# 2043       0.806567     0.937441           0.807292     2.641884
# 1585       0.911336     0.939714           0.818331     2.641480

# %%
movies_to_check = ['Dark',
"In The Dark",
'Black Spot',
'The Rain',
'Dogs of Berlin',
"Black Earth Rising",
'NSU German History X',
'Holiday Secrets',
'13 Reasons Why: Beyond the Reasons',
'The Fear',
"Old Money"]
df_netflix[df_netflix.title.isin(movies_to_check)]
# Out:
#      show_id                               title            director  \
# 2162   s2163                            The Rain                  []
# 2229   s2230                         In The Dark                  []
# 2327   s2328                                Dark                  []
# 3252   s3253                     Holiday Secrets                  []
# 3561   s3562  13 Reasons Why: Beyond the Reasons                  []
# 3746   s3747                          Black Spot                  []
# 4166   s4167                  Black Earth Rising                  []
# 4316   s4317                      Dogs of Berlin                  []
# 5774   s5775                           Old Money    [david, schalko]
# 7623   s7624                NSU German History X                  []
# 8293   s8294                            The Fear  [michael, samuels]
#
#                                                    cast  \
# 2162  [lindberg, lars, tønnesen, mikkel, simonsen, a...
# 2229  [casey, mpumlwana, krantz, sengbloh, morgan, s...
# 2327  [maja, kampwirth, mendl, michael, anatole, seb...
# 3252  [emilie, harfouch, rose, zu, svenja, neumeiste...
# 3561  [dylan, marissa, butler, prentice, selena, tom...
# 3746  [samuel, herzberg, jouy, tiphaine, naidra, rut...
# 4166  [goodman, imani, abena, tunie, michaela, ayivo...
# 4316  [urs, yardim, saß, sinan, anna, maria, fahri, ...
# 5774  [melles, stipsits, strauss, krisch, schwarz, v...
# 7623  [schuch, nina, stetter, urzendowsky, anna, tom...
# 8293  [sidney, bucur, lloyd, ikhile, winter, peter, ...
#
#                            country  \
# 2162  [states, united, denmark, ,]
# 2229              [states, united]
# 2327  [states, united, germany, ,]
# 3252                     [germany]
# 3561              [states, united]
# 3746          [france, belgium, ,]
# 4166             [kingdom, united]
# 4316                     [germany]
# 5774              [states, united]
# 7623                     [germany]
# 8293             [kingdom, united]
#
#                                              listed_in  \
# 2162  [mysteries, dramas, shows, ,, tv, international]
# 2229                     [dramas, shows, ,, tv, crime]
# 2327      [crime, dramas, shows, ,, tv, international]
# 3252             [dramas, shows, ,, tv, international]
# 3561                 [docuseries, shows, ,, tv, crime]
# 3746      [crime, dramas, shows, ,, tv, international]
# 4166    [dramas, shows, british, ,, tv, international]
# 4316      [crime, dramas, shows, ,, tv, international]
# 5774   [comedies, dramas, shows, ,, tv, international]
# 7623      [crime, dramas, shows, ,, tv, international]
# 8293            [dramas, shows, british, ,, tv, crime]
#
#                                             description  \
# 2162  [band, seeking, s, and, –, population, join, a...
# 2229  [turns, blind, in, her, with, when, best, vice...
# 2327  [on, three, families, missing, generations, my...
# 3252  [this, s, in, series, to, of, family, past, a,...
# 3561  [cast, why, members, and, in, mental, themes, ...
# 3746  [crimes, edge, and, in, new, forest, grisly, e...
# 4166  [rwandan, cases, crimes, she, on, her, when, b...
# 4316  [connections, player, case, in, but, soccer, c...
# 5774  [consume, costs, backstabbing, liver, and, new...
# 7623  [neonazi, begins, catch, uphill, national, bat...
# 8293  [aging, dementia, beckett, territory, s, with,...
#
#                               title_list
# 2162                         [the, rain]
# 2229                     [the, dark, in]
# 2327                              [dark]
# 3252                  [holiday, secrets]
# 3561  [beyond, :, the, 13, why, reasons]
# 3746                       [spot, black]
# 4166              [rising, earth, black]
# 4316                  [berlin, of, dogs]
# 5774                        [old, money]
# 7623           [nsu, x, history, german]
# 8293                         [the, fear]
